# %%
# !pip install anthropic

# %% [markdown]
# ### Setup your own API key
# * Login & setup your API key from here (https://console.anthropic.com/settings/keys)
# * Paste your API key in the following inverted commas

# %%
import os
# Set the environment variable within the notebook
os.environ["ANTHROPIC_API_KEY"] = "your_api_key"

# %% [markdown]
# ***Following code is just a sample, your task is to encapsulate this code in a function with arguments of your choice so that function can be reused***

# %% [markdown]
# #### Following link is for reference: https://docs.anthropic.com/en/docs/initial-setup#next-steps

# %%
import anthropic
# importing all the neccesarry libraries
# for data handling
import numpy as np
import pandas as pd
import json

# for web scraping
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

import time
from datetime import date

# %%
client = anthropic.Anthropic()

def queryFun(query):
    response = client.messages.create(
    model="claude-3-5-sonnet-20241022",
    max_tokens=500, # length of the response
    temperature=0, # probability of randomness in output
    # system is the prompt given to set up context
    system="""You are an AI assistant trained to categorize user feedback into predefined categories, 
            along with sentiment analysis for each category. Your goal is to analyze each piece of feedback, 
            assign the most relevant categories Predefined Categories: Food, 
            Staff/Service and Environment. Firstly, analyze all the things is about. Make sure the answer is tab separated 
            first telling all the things it was about then tab then was it good or bad then tab then reason then 
            tab and then review itself. If the review was about more than 1 thing separate each concern with / tab then their
            relevant part of sentence also being separated with a tab
            For example for query: "I enjoyed the food but the service was poor"
            output: "Food/Serivce   I enjoyed the food/but the service was poor"
            Also only variables we're analyzing are food, service/staff and environment. Rest of things like prices, personal information,
            and anything tied to a specific person should be ignored. Also Staff/Service will be singled out as Service
            And lastly put another tab and after it the date but if the date is something like "N days ago". Do not change the year
            subtact N days from today's date and return date in format DD/MM/YYYY also for "Dined on this date" convert date into 
            DD/MM/YY. Also if 2 or more sentences talk about the same thing only keep one part of it and for compound sentences 
            separate concerns around the coordinate conjunctions (for, and, nor, but, or, yet, so). Hence the
            number of concerns will always be the same as the number of relevant sentences
            So final output format will be
            Concern relevant part of sentence   date
            For example:
            input: "I liked the food but it took too long to arrive Dined today (today's date = 12/12/2024)"
            output: "Food/Service\tI liked the food/but it took too long to arrive\t12/12/2024
            input: "I liked the food but it took too long to arrive Dined on March 23rd, 2021 (today's date = 12/12/2024)"
            output: "Food/Service\tI liked the food/but it took too long to arrive\t23/03/2021
            where \t is tab
            format of output: concerns\trelevant part of sentence\tdate
            """,
    # message is what we provide to the Model
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": query
                }
            ]
        }
    ]
)
    return response.content[0].text

# %%
reveiw_div = r"afkKaa-4T28-" # list of reviews (list tag)
reviewer_info = r"_0Uufw15R3a4-" # info about the reveiwers (section tag)
review_class = r"MpiILQAMSSg-" # info about the reviews (div tag)

# meta data getters
reviewer_place = r"POyqzNMT21k- C7Tp-bANpE4-" # branch that was reviewed (p tag)
review_info_div = r"_6rFG6U7PA6M-" # review (div tag)

review_whole_rating = r"yuQYBV659bs-" 
rating_info = r"R9NyqT2lRqw-" # stars div (div tag)
review_stars = r"tSiVMQB9es0-" # number of stars (div tag)

dates_class = "iLkEeQbexGs-"

today = date.today() # todays date
formatted_date = today.strftime("%d/%m/%Y")

# %%
link = r"https://www.opentable.com/r/nobu-downtown-new-york?corrid=6d9decfc-52bf-4a13-b971-bc8d9cddf57e&avt=eyJ2IjoyLCJtIjoxLCJwIjowLCJzIjowLCJuIjowfQ&p=2&sd=2024-12-01T19%3A00%3A00"

driver = webdriver.Chrome()
driver.get(link)

# %%
def scrapeData(driver, reviews:list, cities:list, dates: list, stars:list, ratings: list, names:list):
    found = False
    reloaded = False
    while not found: 
        XPATH_for_cities = rf"//section[@class='{reviewer_info}']//p[@class='{reviewer_place}']"
        XPATH_for_reviews = rf"//div[@class='{review_class}']//div[@class='{review_info_div}']"
        # Find nested element using XPath
        scrapeCities = driver.find_elements(By.XPATH, XPATH_for_cities) # getting cities
        scrapeReviews = driver.find_elements(By.XPATH, XPATH_for_reviews) # getting reviews
        scrapeDates = driver.find_elements(By.XPATH, f"//p[@class='iLkEeQbexGs-']") # getting dates
        scrapeStars = driver.find_elements(By.CSS_SELECTOR, f".R9NyqT2lRqw- .{review_stars}") # getting stars
        scrapeRatings = driver.find_elements(By.CSS_SELECTOR, f".{all_ratings}") # getting ratings   
        scrapeNames = driver.find_elements(By.CSS_SELECTOR, f".{reviewer_name}") # getting names

        if (len(scrapeCities) == 0):
            driver.refresh() # reload pages if things havent been loaded
            time.sleep(1)
            reloaded = True
            continue;
        
        # print(len(scrapeReviews), len(scrapeCities), len(scrapeDates), len(scrapeStars), )
            
        for i in range(len(scrapeReviews)):
            if "Read more" not in scrapeReviews[i].text and len(scrapeReviews[i].text) < 150:
                reviews.append(scrapeReviews[i].text)
                cities.append(scrapeCities[i].text)
                dates.append(scrapeDates[i].text)
                stars.append(scrapeStars[i].get_attribute("innerHTML"))
                ratings.append((scrapeRatings[i].text).replace('\n', ' '))
                names.append(scrapeNames[i].text)
        found = True
    print("Reloaded: ", reloaded)
    return reloaded

    # element = driver.find_elements(By.CSS_SELECTOR, f".{review_class} .{review_info_div}") # commenting for future referencing 
def scrapeResturant(driver):    
    reviews = []
    cities = []
    dates = []
    stars = []
    ratings = []
    names = []

    next_button_class = "ojKcSDzr190- y4S9mw-uCFI- g-dxt-fQ2ZU- C7Tp-bANpE4-"
    next_ = driver.find_elements(By.XPATH, f"//div[@class='TkpxbcBbu80-']//a[@class='{next_button_class}']")
    if len(next_) > 1:
        next_ = next_[1]
    else:
        next_ = next_[0]
        
    while next_.is_displayed():
        scrapeData(driver, reviews, cities, dates, stars, ratings, names) # tells if the page was reloaded
        next_ = driver.find_elements(By.XPATH, f"//div[@class='TkpxbcBbu80-']//a[@class='{next_button_class}']")
        
        # next_.click() # idk why drive click isnt working
        # Using JavaScript to click an element
        
        if len(next_) > 1:
            next_ = next_[1]
            driver.execute_script("arguments[0].click();", next_)
        else:
            next_ = next_[0]
            driver.execute_script("arguments[0].click();", next_)
        time.sleep(1)
    return (reviews, cities, dates, stars, ratings, names)

# %%
reviews = []
stars = [] 
dates = []
cities = []
names = []
ratings = []



def save_to_tsv(file_name: str, content):
    content = pd.DataFrame(content)
    content.to_csv(file_name, sep='\t', index=False, encoding='utf-8')

def save_content(names, dates, cities, reviews, stars): 
    choice = input("Do you want to save you data? (Y/N)")
    if choice == 'Y' or choice == 'y' and len(reviews) > 0:   
        content = {
            "Names":names,
            "dates": dates,
            "cities": cities,
            "reviews": reviews,
            "ratings": ratings,
            "stars": stars
        }

        save_to_tsv('data.tsv', pd.DataFrame(content))
save_content(names, dates, cities, reviews, stars)

def readData():
    global reviews, cities, stars, dates, names, ratings
    choice = input("Read Local (L) or Scrape Data (S)");
    if choice == 'L' or choice == 'l':
        df = pd.read_csv('data.tsv', sep='\t', encoding='utf-8')
        reviews = df['reviews']
        stars = df['stars']
        dates = df['dates']
        cities = df['cities']
        names = df['Names']
        ratings = df['ratings']
        
    elif choice == 'S' or choice == 's':
        choice = int(input("Enter approx number of reviews to scrape: "))
        (reviews, cities, dates, stars, ratings, names) = scrapeResturant(driver)
readData()    
driver.close()

# %%
complete_review = {}

# %%
back_off = 1
MAX_TRIES_PER_QUERY = 3

for i in range(674, 950):
    print(f"Processing review ({i}): {reviews[i]}")
    review = f"{reviews[i]} {dates[i]} (today's date = {formatted_date})"
    tries = 0

    while tries < MAX_TRIES_PER_QUERY:
        try:
            review = queryFun(review)  # Attempt the query
            back_off = 1  # Reset backoff on success
            print("Reviewed!")
            break  # Exit retry loop
        except Exception as e:
            print(f"Error in review ({i}): {reviews[i]} - Attempt {tries + 1} failed. Error: {e}")
            tries += 1
            back_off = min(back_off * 2, 64)  # Cap the backoff to 64 seconds
            time.sleep(back_off)  # Wait before retrying

    # If the query failed after all retries
    if tries == MAX_TRIES_PER_QUERY:
        print(f"Skipping review ({i}) after {MAX_TRIES_PER_QUERY} attempts.")
        back_off = 1
        continue

    # Parse the response
    """Food/Environment Food was good/Environment was bad   Date"""
    # Food/Service   Food was amazing/but Jan was rude to me   11/11/2023
    response = review.split('\t')
    if len(response) < 3:
        continue;
    print(response)
    concerns = response[0].split('/')
    reasons = response[1].split('/')
    date = response[2]
    
    if (len(concerns) != len(reasons)):
        continue;

    if complete_review.get(date, None) is None:
        complete_review[date] = []

    summary = {}
    categories = {}
    for j in range(len(concerns)): 
        if "Food" in concerns[j]:
            categories["Food"] = reasons[j]
        elif "Service" in concerns[j]:
            categories["Service"] = reasons[j]
        elif "Environment" in concerns[j]:
            categories["Environment"] = reasons[j]

    summary['name'] = names[i]
    summary["categories"] = categories
    summary["feedback"] = reviews[i]
    summary['rating'] = ratings[i]
    summary["stars"] = float(stars[i])
    summary["city"] = cities[i]

    complete_review[date].append(summary)
    time.sleep(12)  # Adhere to rate limit

# Output the completed review dictionary
# print(len(complete_review), '\n', complete_review)
# with open('review_analysis.json', 'w') as file:
#     json.dump(complete_review, file, indent=4)
# Out:
# Processing review (674): Too expensive. Service was not that good. Quality is only ok.
# Reviewed!
# ['Service/Food', 'Service was not that good/Quality is only ok', '10/09/2022']
# Processing review (675): Great place and food
# Reviewed!
# ['Environment/Food', 'Great place/and food', '09/09/2022']
# Processing review (676): Fantastic, highly recommended.
# Reviewed!
# ['Food', 'Fantastic, highly recommended', '07/09/2022']
# Processing review (677): Amazing evening! Nobu never disappoints. Fantastic service and food.
# Reviewed!
# ['Food/Service', 'Fantastic service and food', '06/09/2022']
# Processing review (678): Send off dinner
# Reviewed!
# ['Service', 'Send off dinner', '05/09/2022']
# Processing review (679): The Ambience, Cuisine and Service was top Tier. Went for a bday dinner and had a great experience.
# Reviewed!
# ['Environment/Food/Service', 'The Ambience, Cuisine and Service was top Tier', '04/09/2022']
# Processing review (680): Great food!! Service was very good and great atmosphere!
# Reviewed!
# ['Food/Service/Environment', 'Great food/Service was very good/great atmosphere', '03/09/2022']
# Processing review (681): Way overrated. First time I did not finish sushi and the crispy shrimp taste the same as you would get at Bubba Gump.
# Reviewed!
# ['Food', 'First time I did not finish sushi and the crispy shrimp taste the same as you would get at Bubba Gump', '02/09/2022']
# Processing review (682): This is second time we have been to Nobu Downtown. Amazing food and service. Will  definitely return.
# Reviewed!
# ['Food/Service', 'Amazing food and service', '01/09/2022']
# Processing review (683): The food was the best and the service was outstanding! Sushi was so fresh and delicious.
# Reviewed!
# ['Food/Service', 'The food was the best and the service was outstanding', '01/09/2022']
# Processing review (684): Had their tasting menu. Waiter accommodated our food allergies, likes and dislikes. FABULOUS all around. Can’t wait to go back!
# Reviewed!
# ['Food/Service', 'Had their tasting menu/Waiter accommodated our food allergies', '01/09/2022']
# Processing review (685): A classic Nobu
#
# Service was very good
# Reviewed!
# ['Service', 'Service was very good', '31/08/2022']
# Processing review (686): I love Japanese food and even for me it was some of the best food I’ve ever eaten!
# Reviewed!
# ['Food', "it was some of the best food I've ever eaten", '31/08/2022']
# Processing review (687): Food was excellent all around. Will repeat!
# Reviewed!
# ['Food', 'Food was excellent all around', '29/08/2022']
# Processing review (688): Always a great experience!  Thank you so much, Nobu!
# Reviewed!
# ['Service', 'Always a great experience', '26/08/2022']
# Processing review (689): Had a great time. Coming back in a few nights again!
# Reviewed!
# ['None', 'Had a great time', '23/08/2022\n\nNote: This review doesn\'t specifically mention food, service, or environment, so it\'s categorized as "None" since it\'s just a general positive statement.']
# Processing review (690): Love the service our waiter took the time to explain everything
# Reviewed!
# ['Service', 'Love the service our waiter took the time to explain everything', '22/08/2022']
# Processing review (691): So much yum. Waygu much yum. Crispy rice much yum.
# Reviewed!
# ['Food', 'So much yum. Waygu much yum. Crispy rice much yum', '22/08/2022']
# Processing review (692): It was perfect
# Reviewed!
# ['Food/Service/Environment', 'It was perfect', '22/08/2022']
# Processing review (693): A little hurried
# Reviewed!
# ['Service', 'A little hurried', '21/08/2022']
# Processing review (694): Super Wagyu dim sum and tacos; lovely wine selection, poor options in vegetarian food though except the honey corn
# Reviewed!
# ['Food', 'Super Wagyu dim sum and tacos/poor options in vegetarian food though except the honey corn', '19/08/2022']
# Processing review (695): Sat at the sushi bar for the first time and it was the best experience.
# Reviewed!
# ['Environment', 'Sat at the sushi bar for the first time and it was the best experience', '19/08/2022']
# Processing review (696): Excellent service at the bar. Joseph was great and assisted with menu and selections. Fresh fish nicely displayed!
# Sake was fantastic!
# Awesome
# Reviewed!
# ['Service/Food', 'Excellent service at the bar/Fresh fish nicely displayed', '18/08/2022']
# Processing review (697): Great host food was amazing
# Reviewed!
# ['Service/Food', 'Great host/food was amazing', '17/08/2022']
# Processing review (698): Great food great waiters good drinks
# Reviewed!
# ['Food/Service', 'Great food/great waiters', '16/08/2022']
# Processing review (699): Locale veramente bello con un ottimo sushi.. per NY anche economico lo consiglierei, è stata un ottima esperienza.
# Reviewed!
# ['Environment/Food', 'Locale veramente bello/con un ottimo sushi', '15/08/2022']
# Processing review (700): Everything was very good especially the tacos and the wagyu
# Reviewed!
# ['Food', 'Everything was very good especially the tacos and the wagyu', '15/08/2022']
# Processing review (701): Loved it! Will definitely be back!
# Reviewed!
# ['Food/Service/Environment', 'Loved it', "13/08/2022\n\nNote: This is a general positive sentiment but doesn't specifically mention food, service, or environment, so all categories are included as it's a blanket statement about the overall experience."]
# Processing review (702): Poor quality sushi, not worth the money.
#
# NYC has plenty of high quality options.
# Reviewed!
# ['Food', 'Poor quality sushi', '13/08/2022']
# Processing review (703): Amazing food, amazing service! Cannot wait to go back!
# Reviewed!
# ['Food/Service', 'Amazing food/amazing service', '12/08/2022']
# Processing review (704): Staff as always are very attentive, courteous and friendly. Ambience is excellent. Delectable tasty food.
# Reviewed!
# ['Service/Environment/Food', 'Staff as always are very attentive, courteous and friendly/Ambience is excellent/Delectable tasty food', '12/08/2022']
# Processing review (705): Great Food!
# Reviewed!
# ['Food', 'Great Food!', '11/08/2022']
# Processing review (706): Were out of half of their menu on a Wednesday night
# Reviewed!
# ['Food', 'Were out of half of their menu', '11/08/2022']
# Processing review (707): Fantastic as always get the black cod miso and yellowtAil
# Reviewed!
# ['Food', 'Fantastic as always get the black cod miso and yellowtAil', '11/08/2022']
# Processing review (708): Waitstaff was outstanding. Food, incredible. Plum sake was a great way to end the meal.
# Reviewed!
# ['Service/Food', 'Waitstaff was outstanding/Food, incredible', '10/08/2022']
# Processing review (709): Great; food was fantastic and service was good.
# Reviewed!
# ['Food/Service', 'Great; food was fantastic/and service was good', '09/08/2022']
# Processing review (710): Food and drinks was great. Perfect dining experience
# Reviewed!
# ['Food', 'Food and drinks was great', '09/08/2022']
# Processing review (711): Birthday Dinner. Taste and quality of the food is good but way overpriced. The service was just okay too.
# Reviewed!
# ['Food/Service', 'Taste and quality of the food is good/The service was just okay', '08/08/2022']
# Processing review (712): Just perfect!!!!
# Reviewed!
# ['Service', 'Just perfect!!!!', '08/08/2022']
# Processing review (713): Food was ok, not for the price at all. Have no issue spending $250 on dinner, but food was worth $100 tops.. spend your money at a better place.
# Reviewed!
# ['Food', 'food was ok', '07/08/2022']
# Processing review (714): Hot dishes were very good. Sushi rolls were really nothing special.
# Service was very good!
# Reviewed!
# ['Food/Service', 'Hot dishes were very good. Sushi rolls were really nothing special/Service was very good', '06/08/2022']
# Processing review (715): Fun, good vibes excellent food
# Error in review (715): Fun, good vibes excellent food - Attempt 1 failed. Error: Error code: 500 - {'type': 'error', 'error': {'type': 'api_error', 'message': 'Internal server error'}}
# Reviewed!
# ['Environment/Food', 'Fun, good vibes/excellent food', '05/08/2022']
# Processing review (716): Visiting NyC
# Reviewed!
# Processing review (717): Great food and service - very loud hard to hear everyone at the table
# Reviewed!
# ['Food/Service/Environment', 'Great food/and service/very loud hard to hear everyone at the table', '04/08/2022']
# Processing review (718): June is the best
# Reviewed!
# Processing review (719): Food and service was great.  We found the techno music to be a bit annoying and felt that something different would be preferable.
# Reviewed!
# ['Food/Service/Environment', 'Food and service was great/Food and service was great/We found the techno music to be a bit annoying', '03/08/2022']
# Processing review (720): Good experience - dishes were ok and ambience and service was good
# Reviewed!
# ['Food/Environment/Service', 'dishes were ok/ambience was good/service was good', '02/08/2022']
# Processing review (721): All time fav resturant!
# Reviewed!
# ['No specific concerns mentioned', 'All time fav resturant', '01/08/2022']
# Processing review (722): Great spot to bring your wife if 21 years to remind her why New York is New York.  Wall Street 4 life -dan risis
# Reviewed!
# ['Environment', 'Great spot to bring your wife', '28/07/2022']
# Processing review (723): Outstanding experience! Nobu never fails to deliver amazing food and great service.
# Reviewed!
# ['Food/Service', 'Outstanding experience! Nobu never fails to deliver amazing food/and great service', '28/07/2022']
# Processing review (724): Great food! EXCELLENT service! Pretty pricey!
# Reviewed!
# ['Food/Service', 'Great food!/EXCELLENT service!', '28/07/2022']
# Processing review (725): The food was great. The service could be better. We have been here before and in my opinion 57th Street is better.
# Reviewed!
# ['Food/Service', 'The food was great/The service could be better', '25/07/2022']
# Processing review (726): Always great
# Reviewed!
# ['Food/Service/Environment', 'Always great', '25/07/2022']
# Processing review (727): Wonderful as always. Had the chef prepare an assortment of sushi for our group.  Excellent presentation and delicious!
# Reviewed!
# ['Food', 'Wonderful as always/Had the chef prepare an assortment of sushi for our group/Excellent presentation and delicious', '25/07/2022']
# Processing review (728): Day in the city
# Reviewed!
# ['No relevant feedback about Food, Service, or Environment found in this review', 'No relevant feedback', '24/07/2022']
# Processing review (729): biz - connecting with friends and biz partners
# Reviewed!
# Processing review (730): Excellent, great fish, great sauces, wonderful creativity
# Reviewed!
# ['Food', 'Excellent, great fish, great sauces, wonderful creativity', '23/07/2022']
# Processing review (731): Awesome experience!!  Delicious sushi and amazing service!!
# Reviewed!
# ['Food/Service', 'Delicious sushi/amazing service', '22/07/2022']
# Processing review (732): Birthday  Celebrations !! Still the best sushi!!
# Error in review (732): Birthday  Celebrations !! Still the best sushi!! - Attempt 1 failed. Error: Error code: 500 - {'type': 'error', 'error': {'type': 'api_error', 'message': 'Internal server error'}}
# Reviewed!
# ['Food', 'Still the best sushi', '22/07/2022']
# Processing review (733): My second time dining here and it NEVER DISAPPOINTS!
# Reviewed!
# ['Food', 'NEVER DISAPPOINTS!', '22/07/2022']
# Processing review (734): We were rushed to eat and out the restaurant.
# Reviewed!
# ['Service', 'We were rushed to eat and out the restaurant', '21/07/2022']
# Processing review (735): An amazing experience, everything was quite well done.
# Reviewed!
# ['Food/Service/Environment', 'An amazing experience, everything was quite well done', '21/07/2022']
# Processing review (736): This was our first time at this Nobu location. They are very consistent across all the locations we have eaten at.
# Reviewed!
# ['Food', 'They are very consistent across all the locations we have eaten at', '20/07/2022']
# Processing review (737): 18th bday. Daughter
# Reviewed!
# Processing review (738): Fantastic- as always a pleasure going to Nobu. We took the black cod and it was amaizing.
# Reviewed!
# ['Food', 'We took the black cod and it was amaizing', '19/07/2022']
# Processing review (739): Nice environment and great food
# Reviewed!
# ['Environment/Food', 'Nice environment/and great food', '17/07/2022']
# Processing review (740): We had a great meal and our waitress was phenomenal. Everything she recommended was really good.
# Reviewed!
# ['Food/Service', 'We had a great meal/and our waitress was phenomenal', '17/07/2022']
# Processing review (741): Won-der-ful in every way! I wish you had a restaurant of this level in Paris 🔥
# Reviewed!
# ['Food/Service/Environment', 'Won-der-ful in every way', '17/07/2022']
# Processing review (742): Over hyped in pop culture, but the food was great!
# Reviewed!
# ['Food', 'the food was great', '16/07/2022']
# Processing review (743): Great food and great service
# Reviewed!
# ['Food/Service', 'Great food/and great service', '16/07/2022']
# Processing review (744): Everything is delicious 😛
# Reviewed!
# ['Food', 'Everything is delicious', '16/07/2022']
# Processing review (745): Sushi-ok.  Waiter didn’t explain anything.
# Sake fantastic
# Salmon fantastic
# Reviewed!
# ['Food/Service', "Sushi-ok/Waiter didn't explain anything", '15/07/2022']
# Processing review (746): The food is so good. Service was great. The prices are worth it.
# Reviewed!
# ['Food/Service', 'The food is so good/Service was great', '14/07/2022']
# Processing review (747): Reservations was at 8 but were not seated until 8:25 pm. Others that came after us were seated immediately
# Reviewed!
# ['Service', 'Reservations was at 8 but were not seated until 8:25 pm. Others that came after us were seated immediately', '14/07/2022']
# Processing review (748): I visited Nobu downtown. The Service and food was quite good.
# Overall I felt it is overrated.
# It didn't keep up to the hype.
# Reviewed!
# ['Food/Service', 'The Service and food was quite good', '10/07/2022']
# Processing review (749): Great birthday dinner for my girlfriend.
# Reviewed!
# ['Food', 'Great birthday dinner', '10/07/2022']
# Processing review (750): Exceptional. Best meal of our lives.
# Reviewed!
# ['Food', 'Exceptional. Best meal of our lives', '10/07/2022']
# Processing review (751): Delicious, however the tasting menu is very expensive especially with no drink pairings
# Reviewed!
# ['Food', 'Delicious', '09/07/2022']
# Processing review (752): Excellent food and service
# Reviewed!
# ['Food/Service', 'Excellent food and service', '08/07/2022']
# Processing review (753): Great location and setting, outstanding food and service - special thanks to Bryan!
# Reviewed!
# ['Environment/Food/Service', 'Great location and setting/outstanding food/and service', '07/07/2022']
# Processing review (754): This meal was one of the best I've had. Well worth it!
# Reviewed!
# ['Food', "This meal was one of the best I've had", '06/07/2022']
# Processing review (755): Moving to NYC
# Reviewed!
# Processing review (756): Words cannot express this gastronomical experience. Every morsel of food was absolutely delectable. Definitely worth every penny!
# Reviewed!
# ['Food', 'Every morsel of food was absolutely delectable', '02/07/2022']
# Processing review (757): Great food but waiter very pushy and we ordered way too much (overpriced) food as a result. This soured the experience for me.
# Reviewed!
# ['Food/Service', 'Great food/but waiter very pushy', '02/07/2022']
# Processing review (758): Excellent service and food !!!!
# Reviewed!
# ['Food/Service', 'Excellent service and food', '02/07/2022']
# Processing review (759): Todo muy bien! Lo único malo es que las entradas y la comida principal la traen todo al mismo tiempo. Debería ser por etapas!
# Reviewed!
# ['Service', 'las entradas y la comida principal la traen todo al mismo tiempo', '29/06/2022']
# Processing review (760): Best sushi in the world. Service above and beyond.
# Reviewed!
# ['Food/Service', 'Best sushi in the world/Service above and beyond', '28/06/2022']
# Processing review (761): The service was lovely, they promptly refilled our drinks and had great sushi suggestions.
# Reviewed!
# ['Service/Food', 'they promptly refilled our drinks and had great sushi suggestions', '27/06/2022']
# Processing review (762): Great time!
# Reviewed!
# ['Service', 'Great time', '26/06/2022']
# Processing review (763): It was good but not GREAT 57th Street was a better experience
# Reviewed!
# ['Food', 'It was good but not GREAT', '25/06/2022']
# Processing review (764): Great food and service. I will definitely come back when in. New York.
# Reviewed!
# ['Food/Service', 'Great food and service', '23/06/2022']
# Processing review (765): It was great!
# Reviewed!
# ['Food/Service/Environment', 'It was great!', '23/06/2022']
# Processing review (766): Excellent experience! The food was amazing, as always. Our server was great. Nobu never disappoints!
# Reviewed!
# ['Food/Service', 'The food was amazing/Our server was great', '19/06/2022']
# Processing review (767): Me and my friends were in town for a good night; yet, our waiter forgot our food; the service was slow
# Reviewed!
# ['Service', 'yet, our waiter forgot our food/the service was slow', '18/06/2022']
# Processing review (768): Wonderful place and Amazing food 100% recommended
# Reviewed!
# ['Food/Environment', 'Wonderful place/Amazing food', '17/06/2022']
# Processing review (769): Definitely coming back soon! Our waiter Kevin gave us amazing customer service, and the food had us speechless.
# Reviewed!
# ['Service/Food', 'Our waiter Kevin gave us amazing customer service/and the food had us speechless', '17/06/2022']
# Processing review (770): Kevin the bartender kept the drinks great..food decor excellent
# Reviewed!
# ['Service/Food/Environment', 'kept the drinks great/food excellent/decor excellent', '16/06/2022']
# Processing review (771): Fantastic food and ambience!
# Reviewed!
# ['Food/Environment', 'Fantastic food/and ambience', '14/06/2022']
# Processing review (772): In such a perfect place, not lot to be mentioned
# Reviewed!
# ['Environment', 'In such a perfect place', '13/06/2022']
# Processing review (773): Nobu never disappoints, another great dinner with family.
# Error in review (773): Nobu never disappoints, another great dinner with family. - Attempt 1 failed. Error: Connection error.
# Error in review (773): Nobu never disappoints, another great dinner with family. - Attempt 2 failed. Error: Connection error.
# Error in review (773): Nobu never disappoints, another great dinner with family. - Attempt 3 failed. Error: Connection error.
# Skipping review (773) after 3 attempts.
# Processing review (774): So amazing. Beautiful dining room, amazing service, and the most amazing food.
# Error in review (774): So amazing. Beautiful dining room, amazing service, and the most amazing food. - Attempt 1 failed. Error: Connection error.
# Error in review (774): So amazing. Beautiful dining room, amazing service, and the most amazing food. - Attempt 2 failed. Error: Connection error.
# Error in review (774): So amazing. Beautiful dining room, amazing service, and the most amazing food. - Attempt 3 failed. Error: Connection error.
# Skipping review (774) after 3 attempts.
# Processing review (775): We came for my birthday. The food was great, but we took a late reservation and it felt as though they were rushing us out.
# Error in review (775): We came for my birthday. The food was great, but we took a late reservation and it felt as though they were rushing us out. - Attempt 1 failed. Error: Connection error.
# Error in review (775): We came for my birthday. The food was great, but we took a late reservation and it felt as though they were rushing us out. - Attempt 2 failed. Error: Connection error.
# Error in review (775): We came for my birthday. The food was great, but we took a late reservation and it felt as though they were rushing us out. - Attempt 3 failed. Error: Connection error.
# Skipping review (775) after 3 attempts.
# Processing review (776): Very nice restaurant. The food is delicious, the service is very nice!
# Error in review (776): Very nice restaurant. The food is delicious, the service is very nice! - Attempt 1 failed. Error: Connection error.
# Error in review (776): Very nice restaurant. The food is delicious, the service is very nice! - Attempt 2 failed. Error: Connection error.
# Error in review (776): Very nice restaurant. The food is delicious, the service is very nice! - Attempt 3 failed. Error: Connection error.
# Skipping review (776) after 3 attempts.
# Processing review (777): Outstanding.
# Error in review (777): Outstanding. - Attempt 1 failed. Error: Connection error.
# Error in review (777): Outstanding. - Attempt 2 failed. Error: Connection error.
# Error in review (777): Outstanding. - Attempt 3 failed. Error: Connection error.
# Skipping review (777) after 3 attempts.
# Processing review (778): This was an incredible experience with amazing service
# Error in review (778): This was an incredible experience with amazing service - Attempt 1 failed. Error: Connection error.
# Error in review (778): This was an incredible experience with amazing service - Attempt 2 failed. Error: Connection error.
# Error in review (778): This was an incredible experience with amazing service - Attempt 3 failed. Error: Connection error.
# Skipping review (778) after 3 attempts.
# Processing review (779): Great experience.
# Error in review (779): Great experience. - Attempt 1 failed. Error: Connection error.
# Error in review (779): Great experience. - Attempt 2 failed. Error: Connection error.
# Error in review (779): Great experience. - Attempt 3 failed. Error: Connection error.
# Skipping review (779) after 3 attempts.
# Processing review (780): Delicious food. Excellent and friendly service
# Error in review (780): Delicious food. Excellent and friendly service - Attempt 1 failed. Error: Connection error.
# Error in review (780): Delicious food. Excellent and friendly service - Attempt 2 failed. Error: Connection error.
# Error in review (780): Delicious food. Excellent and friendly service - Attempt 3 failed. Error: Connection error.
# Skipping review (780) after 3 attempts.
# Processing review (781): Beautiful bar area. Fast service. Delicious food. Clean and comfortable.
# Error in review (781): Beautiful bar area. Fast service. Delicious food. Clean and comfortable. - Attempt 1 failed. Error: Connection error.
# Error in review (781): Beautiful bar area. Fast service. Delicious food. Clean and comfortable. - Attempt 2 failed. Error: Connection error.
# Error in review (781): Beautiful bar area. Fast service. Delicious food. Clean and comfortable. - Attempt 3 failed. Error: Connection error.
# Skipping review (781) after 3 attempts.
# Processing review (782): The food and service was top notch through and through. Dinner for 2 with some starters and a couple mains was about $250. Lovely place 10/10
# Error in review (782): The food and service was top notch through and through. Dinner for 2 with some starters and a couple mains was about $250. Lovely place 10/10 - Attempt 1 failed. Error: Connection error.
# Error in review (782): The food and service was top notch through and through. Dinner for 2 with some starters and a couple mains was about $250. Lovely place 10/10 - Attempt 2 failed. Error: Connection error.
# Error in review (782): The food and service was top notch through and through. Dinner for 2 with some starters and a couple mains was about $250. Lovely place 10/10 - Attempt 3 failed. Error: Connection error.
# Skipping review (782) after 3 attempts.
# Processing review (783): overall great experience. highly recommend for business meeting or special celebration.
# Error in review (783): overall great experience. highly recommend for business meeting or special celebration. - Attempt 1 failed. Error: Connection error.
# Error in review (783): overall great experience. highly recommend for business meeting or special celebration. - Attempt 2 failed. Error: Connection error.
# Error in review (783): overall great experience. highly recommend for business meeting or special celebration. - Attempt 3 failed. Error: Connection error.
# Skipping review (783) after 3 attempts.
# Processing review (784): This downtown Nobu location is the best one in the city.  The service is exceptional, and the food is a hit.  The mini tacos cannot be missed.
# Error in review (784): This downtown Nobu location is the best one in the city.  The service is exceptional, and the food is a hit.  The mini tacos cannot be missed. - Attempt 1 failed. Error: Connection error.
# Error in review (784): This downtown Nobu location is the best one in the city.  The service is exceptional, and the food is a hit.  The mini tacos cannot be missed. - Attempt 2 failed. Error: Connection error.
# Error in review (784): This downtown Nobu location is the best one in the city.  The service is exceptional, and the food is a hit.  The mini tacos cannot be missed. - Attempt 3 failed. Error: Connection error.
# Skipping review (784) after 3 attempts.
# Processing review (785): Great ambience. All the fish was extremely fresh and delicious
# Error in review (785): Great ambience. All the fish was extremely fresh and delicious - Attempt 1 failed. Error: Connection error.
# Error in review (785): Great ambience. All the fish was extremely fresh and delicious - Attempt 2 failed. Error: Connection error.
# Error in review (785): Great ambience. All the fish was extremely fresh and delicious - Attempt 3 failed. Error: Connection error.
# Skipping review (785) after 3 attempts.
# Processing review (786): Wife’s 30th birthday.
# Error in review (786): Wife’s 30th birthday. - Attempt 1 failed. Error: Connection error.
# Error in review (786): Wife’s 30th birthday. - Attempt 2 failed. Error: Connection error.
# Error in review (786): Wife’s 30th birthday. - Attempt 3 failed. Error: Connection error.
# Skipping review (786) after 3 attempts.
# Processing review (787): Loved it!!!
# Food was spectacular.  Service was also excellent.
# Thx!
# Error in review (787): Loved it!!!
# Food was spectacular.  Service was also excellent.
# Thx! - Attempt 1 failed. Error: Connection error.
# Error in review (787): Loved it!!!
# Food was spectacular.  Service was also excellent.
# Thx! - Attempt 2 failed. Error: Connection error.
# Error in review (787): Loved it!!!
# Food was spectacular.  Service was also excellent.
# Thx! - Attempt 3 failed. Error: Connection error.
# Skipping review (787) after 3 attempts.
# Processing review (788): The food was amazing, The Staff was very polite and kind. The atmosphere warm and welcoming. Great experience, I will be back!
# Error in review (788): The food was amazing, The Staff was very polite and kind. The atmosphere warm and welcoming. Great experience, I will be back! - Attempt 1 failed. Error: Connection error.
# Error in review (788): The food was amazing, The Staff was very polite and kind. The atmosphere warm and welcoming. Great experience, I will be back! - Attempt 2 failed. Error: Connection error.
# Error in review (788): The food was amazing, The Staff was very polite and kind. The atmosphere warm and welcoming. Great experience, I will be back! - Attempt 3 failed. Error: Connection error.
# Skipping review (788) after 3 attempts.
# Processing review (789): Good but not great sushi.  Resting on it’s reputation from years ago.  Miso eggplant was excellent.
# Error in review (789): Good but not great sushi.  Resting on it’s reputation from years ago.  Miso eggplant was excellent. - Attempt 1 failed. Error: Connection error.
# Error in review (789): Good but not great sushi.  Resting on it’s reputation from years ago.  Miso eggplant was excellent. - Attempt 2 failed. Error: Connection error.
# Error in review (789): Good but not great sushi.  Resting on it’s reputation from years ago.  Miso eggplant was excellent. - Attempt 3 failed. Error: Connection error.
# Skipping review (789) after 3 attempts.
# Processing review (790): The staff is pleasant as always. Kevin makes the best drinks at the bar.
# Error in review (790): The staff is pleasant as always. Kevin makes the best drinks at the bar. - Attempt 1 failed. Error: Connection error.
# Error in review (790): The staff is pleasant as always. Kevin makes the best drinks at the bar. - Attempt 2 failed. Error: Connection error.
# Error in review (790): The staff is pleasant as always. Kevin makes the best drinks at the bar. - Attempt 3 failed. Error: Connection error.
# Skipping review (790) after 3 attempts.
# Processing review (791): Celebrated sisters bday! Our flights got canceled so Nobu on a Sunday seemed perfect.  June was amazing, top notch hospitality.
# Error in review (791): Celebrated sisters bday! Our flights got canceled so Nobu on a Sunday seemed perfect.  June was amazing, top notch hospitality. - Attempt 1 failed. Error: Connection error.
# Error in review (791): Celebrated sisters bday! Our flights got canceled so Nobu on a Sunday seemed perfect.  June was amazing, top notch hospitality. - Attempt 2 failed. Error: Connection error.
# Error in review (791): Celebrated sisters bday! Our flights got canceled so Nobu on a Sunday seemed perfect.  June was amazing, top notch hospitality. - Attempt 3 failed. Error: Connection error.
# Skipping review (791) after 3 attempts.
# Processing review (792): Love it !!! Best food ever
# Error in review (792): Love it !!! Best food ever - Attempt 1 failed. Error: Connection error.
# Error in review (792): Love it !!! Best food ever - Attempt 2 failed. Error: Connection error.
# Error in review (792): Love it !!! Best food ever - Attempt 3 failed. Error: Connection error.
# Skipping review (792) after 3 attempts.
# Processing review (793): Excellent food, very nice staff
# We were seated at the counter and it was lovely to see all the preparations
# Error in review (793): Excellent food, very nice staff
# We were seated at the counter and it was lovely to see all the preparations - Attempt 1 failed. Error: Connection error.
# Error in review (793): Excellent food, very nice staff
# We were seated at the counter and it was lovely to see all the preparations - Attempt 2 failed. Error: Connection error.
# Error in review (793): Excellent food, very nice staff
# We were seated at the counter and it was lovely to see all the preparations - Attempt 3 failed. Error: Connection error.
# Skipping review (793) after 3 attempts.
# Processing review (794): Friend visiting in town. Omakase is very good but a little overpriced.
# Error in review (794): Friend visiting in town. Omakase is very good but a little overpriced. - Attempt 1 failed. Error: Connection error.
# Error in review (794): Friend visiting in town. Omakase is very good but a little overpriced. - Attempt 2 failed. Error: Connection error.
# Error in review (794): Friend visiting in town. Omakase is very good but a little overpriced. - Attempt 3 failed. Error: Connection error.
# Skipping review (794) after 3 attempts.
# Processing review (795): Great place for a splurge.  Be sure to ask if they have the wagyu dumplings, they are spectacular!
# Error in review (795): Great place for a splurge.  Be sure to ask if they have the wagyu dumplings, they are spectacular! - Attempt 1 failed. Error: Connection error.
# Error in review (795): Great place for a splurge.  Be sure to ask if they have the wagyu dumplings, they are spectacular! - Attempt 2 failed. Error: Connection error.
# Error in review (795): Great place for a splurge.  Be sure to ask if they have the wagyu dumplings, they are spectacular! - Attempt 3 failed. Error: Connection error.
# Skipping review (795) after 3 attempts.
# Processing review (796): Amazingly delicious! Definitely was full and satisfied.
# Error in review (796): Amazingly delicious! Definitely was full and satisfied. - Attempt 1 failed. Error: Connection error.
# Error in review (796): Amazingly delicious! Definitely was full and satisfied. - Attempt 2 failed. Error: Connection error.
# Error in review (796): Amazingly delicious! Definitely was full and satisfied. - Attempt 3 failed. Error: Connection error.
# Skipping review (796) after 3 attempts.
# Processing review (797): Really not worth the price - you can get better sushi at so many other places
# Error in review (797): Really not worth the price - you can get better sushi at so many other places - Attempt 1 failed. Error: Connection error.
# Error in review (797): Really not worth the price - you can get better sushi at so many other places - Attempt 2 failed. Error: Connection error.
# Error in review (797): Really not worth the price - you can get better sushi at so many other places - Attempt 3 failed. Error: Connection error.
# Skipping review (797) after 3 attempts.
# Processing review (798): Amazing as always. Took care of our special order with ease - wagu dumplings, get them - overall amazing.
# Error in review (798): Amazing as always. Took care of our special order with ease - wagu dumplings, get them - overall amazing. - Attempt 1 failed. Error: Connection error.
# Error in review (798): Amazing as always. Took care of our special order with ease - wagu dumplings, get them - overall amazing. - Attempt 2 failed. Error: Connection error.
# Error in review (798): Amazing as always. Took care of our special order with ease - wagu dumplings, get them - overall amazing. - Attempt 3 failed. Error: Connection error.
# Skipping review (798) after 3 attempts.
# Processing review (799): The food was beyond excellent as we have learned to expect
# Error in review (799): The food was beyond excellent as we have learned to expect - Attempt 1 failed. Error: Connection error.
# Error in review (799): The food was beyond excellent as we have learned to expect - Attempt 2 failed. Error: Connection error.
# Error in review (799): The food was beyond excellent as we have learned to expect - Attempt 3 failed. Error: Connection error.
# Skipping review (799) after 3 attempts.
# Processing review (800): The ambiance, food and service were all exceptional. A bit pricey but worth the splurge.
# Error in review (800): The ambiance, food and service were all exceptional. A bit pricey but worth the splurge. - Attempt 1 failed. Error: Connection error.
# Error in review (800): The ambiance, food and service were all exceptional. A bit pricey but worth the splurge. - Attempt 2 failed. Error: Connection error.
# Error in review (800): The ambiance, food and service were all exceptional. A bit pricey but worth the splurge. - Attempt 3 failed. Error: Connection error.
# Skipping review (800) after 3 attempts.
# Processing review (801): Graduation party
# Error in review (801): Graduation party - Attempt 1 failed. Error: Connection error.
# Error in review (801): Graduation party - Attempt 2 failed. Error: Connection error.
# Error in review (801): Graduation party - Attempt 3 failed. Error: Connection error.
# Skipping review (801) after 3 attempts.
# Processing review (802): Was incredible.
# Error in review (802): Was incredible. - Attempt 1 failed. Error: Connection error.
# Error in review (802): Was incredible. - Attempt 2 failed. Error: Connection error.
# Error in review (802): Was incredible. - Attempt 3 failed. Error: Connection error.
# Skipping review (802) after 3 attempts.
# Processing review (803): Nobu’s food is amazing and their servers are so professional! Such an amazing dinner spot. 10/10
# Error in review (803): Nobu’s food is amazing and their servers are so professional! Such an amazing dinner spot. 10/10 - Attempt 1 failed. Error: Connection error.
# Error in review (803): Nobu’s food is amazing and their servers are so professional! Such an amazing dinner spot. 10/10 - Attempt 2 failed. Error: Connection error.
# Error in review (803): Nobu’s food is amazing and their servers are so professional! Such an amazing dinner spot. 10/10 - Attempt 3 failed. Error: Connection error.
# Skipping review (803) after 3 attempts.
# Processing review (804): Good but it was extremely loud.
# Error in review (804): Good but it was extremely loud. - Attempt 1 failed. Error: Connection error.
# Error in review (804): Good but it was extremely loud. - Attempt 2 failed. Error: Connection error.
# Error in review (804): Good but it was extremely loud. - Attempt 3 failed. Error: Connection error.
# Skipping review (804) after 3 attempts.
# Processing review (805): Sushi was good but not exceptional based on price.
# Error in review (805): Sushi was good but not exceptional based on price. - Attempt 1 failed. Error: Connection error.
# Error in review (805): Sushi was good but not exceptional based on price. - Attempt 2 failed. Error: Connection error.
# Error in review (805): Sushi was good but not exceptional based on price. - Attempt 3 failed. Error: Connection error.
# Skipping review (805) after 3 attempts.
# Processing review (806): Still the best Japanese!  The suave is incredible!
# Error in review (806): Still the best Japanese!  The suave is incredible! - Attempt 1 failed. Error: Connection error.
# Error in review (806): Still the best Japanese!  The suave is incredible! - Attempt 2 failed. Error: Connection error.
# Error in review (806): Still the best Japanese!  The suave is incredible! - Attempt 3 failed. Error: Connection error.
# Skipping review (806) after 3 attempts.
# Processing review (807): Great spot. Food was really good and pricing was not too bad for the quality.
# Error in review (807): Great spot. Food was really good and pricing was not too bad for the quality. - Attempt 1 failed. Error: Connection error.
# Error in review (807): Great spot. Food was really good and pricing was not too bad for the quality. - Attempt 2 failed. Error: Connection error.
# Error in review (807): Great spot. Food was really good and pricing was not too bad for the quality. - Attempt 3 failed. Error: Connection error.
# Skipping review (807) after 3 attempts.
# Processing review (808): Amazing service, amazing meal. Thanks for a great night!
# Error in review (808): Amazing service, amazing meal. Thanks for a great night! - Attempt 1 failed. Error: Connection error.
# Error in review (808): Amazing service, amazing meal. Thanks for a great night! - Attempt 2 failed. Error: Connection error.
# Error in review (808): Amazing service, amazing meal. Thanks for a great night! - Attempt 3 failed. Error: Connection error.
# Skipping review (808) after 3 attempts.
# Processing review (809): Sashimi was not fresh. Way better spots for sushi
# Error in review (809): Sashimi was not fresh. Way better spots for sushi - Attempt 1 failed. Error: Connection error.
# Error in review (809): Sashimi was not fresh. Way better spots for sushi - Attempt 2 failed. Error: Connection error.
# Error in review (809): Sashimi was not fresh. Way better spots for sushi - Attempt 3 failed. Error: Connection error.
# Skipping review (809) after 3 attempts.
# Processing review (810): Great Restaurant! Love this place, the food was amazing
# Error in review (810): Great Restaurant! Love this place, the food was amazing - Attempt 1 failed. Error: Connection error.
# Error in review (810): Great Restaurant! Love this place, the food was amazing - Attempt 2 failed. Error: Connection error.
# Error in review (810): Great Restaurant! Love this place, the food was amazing - Attempt 3 failed. Error: Connection error.
# Skipping review (810) after 3 attempts.
# Processing review (811): As always, so good!!
# Error in review (811): As always, so good!! - Attempt 1 failed. Error: Connection error.
# Error in review (811): As always, so good!! - Attempt 2 failed. Error: Connection error.
# Error in review (811): As always, so good!! - Attempt 3 failed. Error: Connection error.
# Skipping review (811) after 3 attempts.
# Processing review (812): Wonderful! Everything from service to good was great. I was Matsuhisha Denver a month ago and the food at Nobu downtown was superior (Sorry Denver).
# Error in review (812): Wonderful! Everything from service to good was great. I was Matsuhisha Denver a month ago and the food at Nobu downtown was superior (Sorry Denver). - Attempt 1 failed. Error: Connection error.
# Error in review (812): Wonderful! Everything from service to good was great. I was Matsuhisha Denver a month ago and the food at Nobu downtown was superior (Sorry Denver). - Attempt 2 failed. Error: Connection error.
# Error in review (812): Wonderful! Everything from service to good was great. I was Matsuhisha Denver a month ago and the food at Nobu downtown was superior (Sorry Denver). - Attempt 3 failed. Error: Connection error.
# Skipping review (812) after 3 attempts.
# Processing review (813): Recommendations were excellent, food delicious, service fantastic
# Error in review (813): Recommendations were excellent, food delicious, service fantastic - Attempt 1 failed. Error: Connection error.
# Error in review (813): Recommendations were excellent, food delicious, service fantastic - Attempt 2 failed. Error: Connection error.
# Error in review (813): Recommendations were excellent, food delicious, service fantastic - Attempt 3 failed. Error: Connection error.
# Skipping review (813) after 3 attempts.
# Processing review (814): Food wasn’t that warm when brought to the table.
# Error in review (814): Food wasn’t that warm when brought to the table. - Attempt 1 failed. Error: Connection error.
# Error in review (814): Food wasn’t that warm when brought to the table. - Attempt 2 failed. Error: Connection error.
# Error in review (814): Food wasn’t that warm when brought to the table. - Attempt 3 failed. Error: Connection error.
# Skipping review (814) after 3 attempts.
# Processing review (815): Kevin was the absolute best! Fantastic server, so friendly and professional, absolutely made the night a great experience for the team
# Error in review (815): Kevin was the absolute best! Fantastic server, so friendly and professional, absolutely made the night a great experience for the team - Attempt 1 failed. Error: Connection error.
# Error in review (815): Kevin was the absolute best! Fantastic server, so friendly and professional, absolutely made the night a great experience for the team - Attempt 2 failed. Error: Connection error.
# Error in review (815): Kevin was the absolute best! Fantastic server, so friendly and professional, absolutely made the night a great experience for the team - Attempt 3 failed. Error: Connection error.
# Skipping review (815) after 3 attempts.
# Processing review (816): Mother’s Day
# Error in review (816): Mother’s Day - Attempt 1 failed. Error: Connection error.
# Error in review (816): Mother’s Day - Attempt 2 failed. Error: Connection error.
# Error in review (816): Mother’s Day - Attempt 3 failed. Error: Connection error.
# Skipping review (816) after 3 attempts.
# Processing review (817): Great meal and service!
# Error in review (817): Great meal and service! - Attempt 1 failed. Error: Connection error.
# Error in review (817): Great meal and service! - Attempt 2 failed. Error: Connection error.
# Error in review (817): Great meal and service! - Attempt 3 failed. Error: Connection error.
# Skipping review (817) after 3 attempts.
# Processing review (818): Great ambiance and atmosphere. Amazing food. I'd definitely go again when I'm in New York.
# Error in review (818): Great ambiance and atmosphere. Amazing food. I'd definitely go again when I'm in New York. - Attempt 1 failed. Error: Connection error.
# Error in review (818): Great ambiance and atmosphere. Amazing food. I'd definitely go again when I'm in New York. - Attempt 2 failed. Error: Connection error.
# Reviewed!
# ['Environment/Food', 'Great ambiance and atmosphere/Amazing food', '08/05/2022']
# Processing review (819): Utstanding!!
# Reviewed!
# ['Service', 'Utstanding!!', '08/05/2022']
# Processing review (820): Good family dinner
# Ambiance is excellent and server was on point
# Reviewed!
# ['Environment/Service', 'Ambiance is excellent/and server was on point', '08/05/2022']
# Processing review (821): Mother’s Day with my mom. Special way to celebrate
# Reviewed!
# ['No relevant feedback about Food, Service, or Environment', 'No relevant feedback about Food, Service, or Environment', '08/05/2022']
# Processing review (822): Great food, service, environment and drinks. Very accommodating.
# Reviewed!
# ['Food/Service/Environment', 'Great food/service/environment', '08/05/2022']
# Processing review (823): Slow service
# I don’t know if making a reservation thru the app always gets us the last table in the corner… always…
# Reviewed!
# ['Service', 'Slow service', '07/05/2022']
# Processing review (824): First time there, great service and exceptional food.
# Reviewed!
# ['Food/Service', 'exceptional food/great service', '07/05/2022']
# Processing review (825): Wagyu nigiri was hands down the best. Everyone loved it more than anything. Even better than the uni
# Reviewed!
# ['Food', 'Wagyu nigiri was hands down the best', '05/05/2022']
# Processing review (826): The food and service was great.
# The dessert was even better.
# Very friendly atmosphere and upbeat.
# Reviewed!
# ['Food/Service/Environment', 'The food and service was great/The dessert was even better/Very friendly atmosphere and upbeat', '04/05/2022']
# Processing review (827): Never again. Never. Nothing like the Tribeca location, which if they were aiming to put that wonderful chapter to bed, they very much succeeded.
# Reviewed!
# ['Service', 'Nothing like the Tribeca location', '04/05/2022']
# Processing review (828): Was amazing and the staff are so friendly
# Reviewed!
# ['Service', 'the staff are so friendly', '03/05/2022']
# Processing review (829): Good for date night
# Reviewed!
# ['Environment', 'Good for date night', '02/05/2022']
# Processing review (830): It was a birthday celebration but we didn’t get the candle in our dessert which was a bit disappointing.
# Reviewed!
# ['Service', "we didn't get the candle in our dessert which was a bit disappointing", '30/04/2022']
# Processing review (831): It was great
# Reviewed!
# Processing review (832): Wonderful!   Everything was amazing
# Reviewed!
# ['Food/Service/Environment', 'Everything was amazing', '30/04/2022']
# Processing review (833): Best date with the love of my life, Marky
# Reviewed!
# ['No relevant concerns as the feedback only contains personal information', 'No relevant sentences', '28/04/2022']
# Processing review (834): Everything was fantastic!!
# Reviewed!
# ['Food/Service/Environment', 'Everything was fantastic', '28/04/2022']
# Processing review (835): Fabulous food, atmosphere and service!  Our server, Eriko, was amazing - loved her!
# Reviewed!
# ['Food/Service/Environment', 'Fabulous food/Fabulous service/Fabulous atmosphere', '28/04/2022']
# Processing review (836): The Code dish was disappointing
# Price is on the very high size
# Reviewed!
# ['Food', 'The Code dish was disappointing', '28/04/2022']
# Processing review (837): Worst service ever. Also had fruit flies flying around my food.
# Reviewed!
# ['Service/Environment', 'Worst service ever/had fruit flies flying around my food', '26/04/2022']
# Processing review (838): Nobu never disappoints - great service beautiful space great vibe
# Reviewed!
# ['Service/Environment', 'great service/beautiful space great vibe', '25/04/2022']
# Processing review (839): Wow! Gorgeous ground level space, impeccable service, and gorgeous scrumptious food. Perfection!
# Reviewed!
# ['Environment/Service/Food', 'Gorgeous ground level space/impeccable service/gorgeous scrumptious food', '25/04/2022']
# Processing review (840): Amazing, the service was perfect felt taken care at every step of the experience
# Reviewed!
# ['Service', 'Amazing, the service was perfect felt taken care at every step of the experience', '24/04/2022']
# Processing review (841): Fantastic food and service
# Reviewed!
# ['Food/Service', 'Fantastic food and service', '23/04/2022']
# Processing review (842): Everything was great.
# Reviewed!
# ['Food/Service/Environment', 'Everything was great', '23/04/2022']
# Processing review (843): Always the best
# Reviewed!
# ['Food/Service/Environment', 'Always the best', '22/04/2022']
# Processing review (844): Was a great experience nice and relaxing
# Reviewed!
# ['Environment', 'Was a great experience nice and relaxing', '22/04/2022']
# Processing review (845): The food was amazing and the waitress was incredibly helpful!
# Reviewed!
# ['Food/Service', 'The food was amazing/and the waitress was incredibly helpful', '22/04/2022']
# Processing review (846): Great experience, great food.
# Reviewed!
# ['Food', 'great food', '22/04/2022']
# Processing review (847): Todo perfecto, ambiente y comida espectacular. Ubicación muy buena.
# Reviewed!
# ['Food/Environment', 'Todo perfecto, ambiente y comida espectacular', '21/04/2022']
# ...
# Reviewed!
# ['Food', 'Hot dishes and dessert is good, but sushi ok not wow', '04/04/2022']
# Processing review (863): Every time we go I wonder why we don't go  more often.  A truly special treat
# Reviewed!
# ['Food', 'A truly special treat', '04/04/2022']
# Processing review (864): This is my second time here. Both times I was impressed with every item we ordered. Service was excellent. This is probably my favorite restaurant.
# Reviewed!
# ['Food/Service', 'Both times I was impressed with every item we ordered/Service was excellent', '03/04/2022']
# Processing review (865): A special event to eat wonderful sushi at extraordinary prices.
# Reviewed!
# ['Food', 'A special event to eat wonderful sushi', '03/04/2022']
# Processing review (866): The service, food quality and ambiance were all terrific!
# Reviewed!
# ['Food/Service/Environment', 'The service, food quality and ambiance were all terrific', '01/04/2022']
# Processing review (867): Great food as always. Service was not warm from front door through meal. Nothing terrible but did not feel as welcome as we should have been.
# Reviewed!
# ['Food/Service', 'Great food as always/Service was not warm from front door through meal', '31/03/2022']
# Processing review (868): It was my first time at Nobu and it was amazing! Service is awesome, food is great. Definitely a place you should try at least once.
# Reviewed!
# ['Food/Service', 'food is great/Service is awesome', '28/03/2022']
# Processing review (869): Enjoyed a fantastic birthday dinner - would highly recommend it as a great place to celebrate a special night.   Food, drink, atmosphere - all 100%!
# Reviewed!
# ['Food/Service/Environment', 'Food, drink, atmosphere - all 100%', '27/03/2022']
# Processing review (870): The most amazing food and service, our favorite spot for special occasions!
# Reviewed!
# ['Food/Service', 'The most amazing food/and service', '27/03/2022']
# Processing review (871): A little loud but otherwise amazing experience!  Food and service were perfect.
# Reviewed!
# ['Environment/Food/Service', 'A little loud/Food and service were perfect', '27/03/2022']
# Processing review (872): Amazing per usual
# Reviewed!
# ['Service', 'Amazing per usual', '26/03/2022']
# Processing review (873): Excellent service and amazing food!
# Reviewed!
# ['Service/Food', 'Excellent service/and amazing food', '26/03/2022']
# Processing review (874): Clearly a very hip place, but also very good food and beautiful surroundings.
# Reviewed!
# ['Environment/Food', 'beautiful surroundings/very good food', '26/03/2022']
# Processing review (875): It’s delicious food and they accommodated very well celiac disease with gluten free dishes without cross contamination!
# Reviewed!
# ['Food/Service', "It's delicious food/they accommodated very well celiac disease with gluten free dishes without cross contamination", '26/03/2022']
# Processing review (876): Excellent food
# Great server
# Reviewed!
# ['Food/Service', 'Excellent food/Great server', '26/03/2022']
# Processing review (877): Ruins one for sushi any place else. Food was amazing. Service impeccable.
# Reviewed!
# ['Food/Service', 'Food was amazing/Service impeccable', '23/03/2022']
# Processing review (878): Great quality, good cocktails, and the bar area was very comfortable
# Reviewed!
# ['Food/Environment', 'Great quality/and the bar area was very comfortable', '20/03/2022']
# Processing review (879): Nothing special…..except that this restaurant is situated inside of the historic building. Other than that, nothing special about this place.
# Reviewed!
# ['Environment', 'this restaurant is situated inside of the historic building', '20/03/2022']
# Processing review (880): Lovely restaurant….would definitely recommend
# Reviewed!
# ['Environment', 'Lovely restaurant', '20/03/2022']
# Processing review (881): I brought my sister on her visit to NYC and we can’t stop talking about it!
# Reviewed!
# Processing review (882): Chef Armando was the best! Every single dish he presented to us was just perfect. Best dinner ever.
# Reviewed!
# ['Food', 'Every single dish he presented to us was just perfect', '17/03/2022']
# Processing review (883): service was not good last night
# Reviewed!
# ['Service', 'service was not good', '17/03/2022']
# Processing review (884): great food. great ambiance. service was good
# Reviewed!
# ['Food/Environment/Service', 'great food/great ambiance/service was good', '15/03/2022']
# Processing review (885): Nobu is always great!! Food is always a wonderful experience.
# Reviewed!
# ['Food', 'Food is always a wonderful experience', '14/03/2022']
# Processing review (886): Birthday celebration was great
# Reviewed!
# ['Environment', 'Birthday celebration was great', '13/03/2022']
# Processing review (887): Food and atmosphere were  really good
# Reviewed!
# ['Food/Environment', 'Food and atmosphere were really good', '13/03/2022']
# Processing review (888): It's a great experience, but prepare your wallet :)
# Reviewed!
# ['Food', "It's a great experience", '11/03/2022']
# Processing review (889): the restaurant has a large selection of dishes, the sushi plate I ordered was not very good
# Reviewed!
# ['Food', 'the sushi plate I ordered was not very good', '11/03/2022']
# Processing review (890): Had a great time! The food, drinks, and service were excellent. Our server was extremely knowledgeable and helpful. Would definitely recommend.
# Reviewed!
# ['Food/Service', 'The food, drinks, and service were excellent/Our server was extremely knowledgeable and helpful', '09/03/2022']
# Processing review (891): Great place to de-stress and enjoy good food! WELL DONE!
# Reviewed!
# ['Food/Environment', 'Great place to de-stress/and enjoy good food', '09/03/2022']
# Processing review (892): Good food. Serving sizes could be a little bigger
# Reviewed!
# ['Food', 'Good food', '08/03/2022']
# Processing review (893): Great food and atmosphere was amazing!  Very busy on a Monday evening!
# Reviewed!
# ['Food/Environment', 'Great food/and atmosphere was amazing', '08/03/2022']
# Processing review (894): We had a very enjoyable meal. The food and service were excellent. The fish is very fresh.
# Reviewed!
# ['Food/Service', 'The food and service were excellent/The fish is very fresh', '07/03/2022']
# Processing review (895): The service and food were impeccable. Cannot wait to go back!
# Reviewed!
# ['Food/Service', 'The service and food were impeccable', '06/03/2022']
# Processing review (896): Food is outstanding! Service was impeccable..The restaurant is loud and very dark.
# Reviewed!
# ['Food/Service/Environment', 'Food is outstanding!/Service was impeccable/The restaurant is loud and very dark', '06/03/2022']
# Processing review (897): It was a phenomenal meal. Our waitress was so kind and made sure that we always had something on the table. An amazing first date experience!
# Reviewed!
# ['Food/Service', 'It was a phenomenal meal/Our waitress was so kind and made sure that we always had something on the table', '06/03/2022']
# Processing review (898): Food was delicious I have zero complaints . First time  there and was very pleased. Our host gave us excellent dinner suggestions
# Reviewed!
# ['Food/Service', 'Food was delicious/Our host gave us excellent dinner suggestions', '06/03/2022']
# Processing review (899): Birthday Dinner with Family
# Reviewed!
# ['No relevant feedback about Food, Service, or Environment was provided in this review', 'N/A', '05/03/2022']
# Processing review (900): Amazing service. The food was out of this world. Drinks were excellent. Totally recommend!
# Reviewed!
# ['Service/Food', 'Amazing service/The food was out of this world', '05/03/2022']
# Processing review (901): Rushed out, not able to have a nicely paced meal
# Reviewed!
# ['Service', 'Rushed out, not able to have a nicely paced meal', '03/03/2022']
# Processing review (902): All hot dishes from Chef’s menu served at the same time. No chance to eat them even warm.
# Reviewed!
# ['Service', 'No chance to eat them even warm', '03/03/2022']
# Processing review (903): Nobu was everything we expected. I want to go back ASAP!
# Reviewed!
# ['Food', 'Nobu was everything we expected', '02/03/2022']
# Processing review (904): Great night out! High quality food and very knowledgeable staff…recommendations 100% !!! Wish I could dine here every night !!
# Reviewed!
# ['Food/Service', 'High quality food/very knowledgeable staff', '27/02/2022']
# Processing review (905): Anniversary
# Reviewed!
# Processing review (906): Reunited cousins after pandemic!!!
# Reviewed!
# Processing review (907): Beautiful interiors, excellent service, delicious food
# Reviewed!
# ['Environment/Service/Food', 'Beautiful interiors/excellent service/delicious food', '25/02/2022']
# Processing review (908): Went for dinner for my daughter’s birthday. The food was delicious and the drinks were on point 👌🏾
# Reviewed!
# ['Food', 'The food was delicious and the drinks were on point', '25/02/2022']
# Processing review (909): Very helpful staff and food was very good.
# We had vegetable sushi and some desserts.
# Everything was fresh and tasted great
# Reviewed!
# ['Service/Food', 'Very helpful staff/food was very good and tasted great', '23/02/2022']
# Processing review (910): amazing food
# Reviewed!
# ['Food', 'amazing food', '21/02/2022']
# Processing review (911): Service was really good and food even better. The atmosphere was really nice.
# Reviewed!
# ['Service/Food/Environment', 'Service was really good/and food even better/The atmosphere was really nice', '20/02/2022']
# Processing review (912): Great dinner as usual. Pricy but you know what your getting. Waiter made excellent recommendations
# Reviewed!
# ['Food/Service', 'Great dinner as usual/Waiter made excellent recommendations', '20/02/2022']
# Processing review (913): Delicioso y el
# Servicio excelente
# Reviewed!
# ['Food/Service', 'Delicioso/Servicio excelente', '19/02/2022']
# Processing review (914): Everything good apart from
# The debris that fell on our heads!  But the manager was excellent
# Reviewed!
# ['Environment/Service', 'The debris that fell on our heads/But the manager was excellent', '18/02/2022']
# Processing review (915): Food is amazing but very expensive
# Reviewed!
# ['Food', 'Food is amazing', '18/02/2022']
# Processing review (916): Such a noticeable upgrade from 'everyday' sushi -- the fish was superb and our meal was fantastic, thank you.
# Reviewed!
# ['Food', 'the fish was superb and our meal was fantastic', '17/02/2022']
# Processing review (917): Valentine’s Day (after) diner was excellent! Definitely going again.
# Reviewed!
# ['Food', "Valentine's Day diner was excellent", '16/02/2022']
# Processing review (918): Cold and hot dishes are amazing, as well as the desserts. For sushi, I was expecting better, so found it to be quite overhyped.
# Reviewed!
# ['Food', 'Cold and hot dishes are amazing, as well as the desserts/For sushi, I was expecting better', '16/02/2022']
# Processing review (919): Overall a great experience and what one would expect from Nobu restaurants worldwide!
# Reviewed!
# ['Food/Service/Environment', 'Overall a great experience and what one would expect from Nobu restaurants worldwide', '16/02/2022']
# Processing review (920): LOVE Nobu! The food is always amazing, the service impeccable, great atmosphere, and my teen daughters felt like Queens! We'll be back.
# Reviewed!
# ['Food/Service/Environment', 'The food is always amazing/the service impeccable/great atmosphere', '16/02/2022']
# Processing review (921): Valentine’s Day dinner was amazing! Food is great!
# Reviewed!
# ['Food', 'Food is great', '15/02/2022']
# Processing review (922): The food was okay, staff didn’t feel friendly. Ambience was great though.
# Reviewed!
# ['Food/Service/Environment', "The food was okay/staff didn't feel friendly/Ambience was great though", '15/02/2022']
# Processing review (923): Everything was great except for the gnats flying around the table!
# Reviewed!
# ['Environment', 'gnats flying around the table', '15/02/2022']
# Processing review (924): We thought the food for the Valentines dinner was creative and fun- service as always was excellent! Nice buzz.
# Reviewed!
# ['Food/Service/Environment', 'We thought the food for the Valentines dinner was creative and fun/service as always was excellent/Nice buzz', '15/02/2022']
# Processing review (925): Food and service very good, but miss the omakase option.
# Reviewed!
# ['Food/Service', 'Food and service very good', '14/02/2022']
# Processing review (926): Great food
# Reviewed!
# ['Food', 'Great food', '13/02/2022']
# Processing review (927): Sooooo good. Highly recommend. Somewhat tapas style.
# Reviewed!
# ['Food', 'Sooooo good', '12/02/2022']
# Processing review (928): Had such a calm amazing time at Nobu Downtown. Service was Top 5, no debate. I enjoyed every moment. Highly Recommended !
# Reviewed!
# ['Service', 'Service was Top 5', '12/02/2022']
# Processing review (929): Amazing! We left our entire order up to our server and she brought out one delicious dish after another!!
# Reviewed!
# ['Service', 'Amazing! We left our entire order up to our server and she brought out one delicious dish after another', '12/02/2022']
# Processing review (930): definitely get the spicy tuna with rice app. our bartender upstairs was the best
# Reviewed!
# ['Food/Service', 'definitely get the spicy tuna with rice/our bartender upstairs was the best', '12/02/2022']
# Processing review (931): Nobu downtown is a wonderful restaurant with a nice atmosphere, great food and drink.  Recommended.
# Reviewed!
# ['Environment/Food', 'a nice atmosphere/great food and drink', '08/02/2022']
# Processing review (932): Always 10/10 experience..
# Reviewed!
# ['Service', 'Always 10/10 experience', '06/02/2022']
# Processing review (933): The food and service was fantastic and it wasn’t to loud even though the restaurant was full. Definitely recommend
# Reviewed!
# ['Food/Service/Environment', "The food and service was fantastic/and it wasn't to loud even though the restaurant was full", '06/02/2022']
# Processing review (934): Can’t miss with Nobu.
# Reviewed!
# ['Food', "Can't miss with Nobu", '04/02/2022']
# Processing review (935): food was great
# Reviewed!
# ['Food', 'food was great', '30/01/2022']
# Processing review (936): Way over priced for average food and crappy service.
# Reviewed!
# ['Food/Service', 'average food/crappy service', '29/01/2022']
# Processing review (937): Amazing. We had a wonderful time.
# Reviewed!
# ['Service', 'Amazing. We had a wonderful time', '29/01/2022']
# Processing review (938): Excellent atmosphere and great food with a twist..
# Reviewed!
# ['Environment/Food', 'Excellent atmosphere/great food with a twist', '29/01/2022']
# Processing review (939): Incredible experience. A great spin on high quality Japanese cuisine.
#
# Great spot for a date. DEFINITELY get a reservation ahead of time.
# Reviewed!
# ['Food/Environment', 'A great spin on high quality Japanese cuisine/Great spot for a date', '29/01/2022']
# Processing review (940): Amazing food and vibe 10/10 will be back soon.
# Reviewed!
# ['Food/Environment', 'Amazing food/and vibe', '25/01/2022']
# Processing review (941): Decent. Food was really good. And it’s was made quickly.
# Reviewed!
# ['Food/Service', "Food was really good/And it's was made quickly", '22/01/2022']
# Processing review (942): Amazing food and service!
# Reviewed!
# ['Food/Service', 'Amazing food/and service', '22/01/2022']
# Processing review (943): The best sushi in NYC ❤️❤️I love nobu
# Reviewed!
# ['Food', 'The best sushi in NYC', '21/01/2022']
# Processing review (944): Food was amazing
# Reviewed!
# ['Food', 'Food was amazing', '18/01/2022']
# Processing review (945): Literally my favorite restaurant. It’s 5/5 every time and the martini espresso is to die for!!
# Reviewed!
# ['Food', 'the martini espresso is to die for', '17/01/2022']
# Processing review (946): Really great time and food. We really enjoyed our date night at Nobu.
# Reviewed!
# ['Food', 'Really great time and food', '16/01/2022']
# Processing review (947): The street level bar area was gorgeous! Excellent atmosphere, service and food. Will visit again.
# Reviewed!
# ['Environment/Service/Food', 'The street level bar area was gorgeous/Excellent service/Excellent food', '16/01/2022']
# Processing review (948): It was good
# Reviewed!
# Processing review (949): Birthday celebration
# Reviewed!

# %%
print(len(complete_review), '\n', complete_review)
#next time append donot write
with open('review_analysis.json', 'w') as file:
    json.dump(complete_review, file, indent=4)
# Out:
# 492
#  {'11/12/2024': [{'name': 'Jeff', 'categories': {'Food': 'Food incredible'}, 'feedback': 'Always amazing dining experience.\nFood incredible. A must stop in NYC.', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 4.7, 'city': 'Charleston'}], '10/12/2024': [{'name': 'Stacey', 'categories': {'Food': 'Nobu is excellent'}, 'feedback': 'Nobu is excellent as always! Always my favorite restaurant.', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 4.7, 'city': 'Orlando'}, {'name': 'CC', 'categories': {'Food': 'Great dinner', 'Service': 'and great, fast service'}, 'feedback': 'Great dinner and great, fast service. The food was excellent.', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'New York City'}], '06/12/2024': [{'name': 'Yvonne', 'categories': {'Service': 'She said two very obnoxious things on the way out'}, 'feedback': 'It was all excellent except for the rude coat check girl. She said two very obnoxious things on the way out. Not acceptable.', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'Toronto'}], '05/12/2024': [{'name': 'OpenTable Diner', 'categories': {'Food': 'Bad quality fish. No rolling skills'}, 'feedback': 'Terrible terrible terrible. Tourist trap. Bad sushi. Bad quality fish. No rolling skills. Bad.', 'rating': 'Overall 1 Food 1 Service 1 Ambience 1', 'stars': 5.0, 'city': 'Orlando'}], '01/12/2024': [{'name': 'Elie', 'categories': {'Service': 'Amazing as always'}, 'feedback': 'Amazing as always love this place will always be back', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 3.0, 'city': 'New York City'}], '30/11/2024': [{'name': 'Janet', 'categories': {'Food': 'The food is consistently fabulous'}, 'feedback': 'A wonderful treat! The food is consistently fabulous.', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 1.0, 'city': 'New York City'}, {'name': 'Donald', 'categories': {'Service': 'Service staff from check in until leaving did a great job', 'Food': 'Food was great'}, 'feedback': 'Service staff from check in until leaving did a great job. Food was great.', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'Anchorage'}], '28/11/2024': [{'name': 'Manish', 'categories': {'Service': 'they have less ppl', 'Food': 'and food is much much better'}, 'feedback': 'Service was not so good , they have less ppl and food on 57 st location is much much better', 'rating': 'Overall 2 Food 2 Service 2 Ambience 5', 'stars': 4.7, 'city': 'New York City'}], '24/11/2024': [{'name': 'Erik', 'categories': {'Service': 'Outstanding service', 'Environment': 'and beautiful place to eat and enjoy'}, 'feedback': 'Outstanding service and beautiful place to eat and enjoy!', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 2.0, 'city': 'Richmond'}, {'name': 'Kara', 'categories': {'Food': 'Excellent food', 'Service': 'excellent service'}, 'feedback': 'Excellent experience excellent food excellent service', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'New York City'}, {'name': 'Frank', 'categories': {'Service': 'Joseph and June are the best servers in the place'}, 'feedback': 'Incredible as usual. Joseph and June are the best servers in the place', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'New York City'}], '23/11/2024': [{'name': 'terri', 'categories': {'Food': 'the food was amazing'}, 'feedback': 'We went for my moms 84th birthday.  Everything was perfect and the food was amazing!', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'Columbus'}], '22/11/2024': [{'name': 'Sami', 'categories': {'Service': 'starting at the bar and finalized in the restaurant'}, 'feedback': 'Another great night starting at the bar and finalized in the restaurant..👏', 'rating': 'Overall 5 Food 5 Service 5 Ambience 5', 'stars': 5.0, 'city': 'Berlin'}], '19/11/2024': [{'name': 'Maria Antónia', 'categories': {'Food': 'Rock shrimp is a must', 'Servic ...

# %%
complete_review
# Out:
# {'11/12/2024': [{'name': 'Jeff',
#    'categories': {'Food': 'Food incredible'},
#    'feedback': 'Always amazing dining experience.\nFood incredible. A must stop in NYC.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Charleston'}],
#  '10/12/2024': [{'name': 'Stacey',
#    'categories': {'Food': 'Nobu is excellent'},
#    'feedback': 'Nobu is excellent as always! Always my favorite restaurant.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Orlando'},
#   {'name': 'CC',
#    'categories': {'Food': 'Great dinner',
#     'Service': 'and great, fast service'},
#    'feedback': 'Great dinner and great, fast service. The food was excellent.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '06/12/2024': [{'name': 'Yvonne',
#    'categories': {'Service': 'She said two very obnoxious things on the way out'},
#    'feedback': 'It was all excellent except for the rude coat check girl. She said two very obnoxious things on the way out. Not acceptable.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Toronto'}],
#  '05/12/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Bad quality fish. No rolling skills'},
#    'feedback': 'Terrible terrible terrible. Tourist trap. Bad sushi. Bad quality fish. No rolling skills. Bad.',
#    'rating': 'Overall 1 Food 1 Service 1 Ambience 1',
#    'stars': 5.0,
#    'city': 'Orlando'}],
#  '01/12/2024': [{'name': 'Elie',
#    'categories': {'Service': 'Amazing as always'},
#    'feedback': 'Amazing as always love this place will always be back',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '30/11/2024': [{'name': 'Janet',
#    'categories': {'Food': 'The food is consistently fabulous'},
#    'feedback': 'A wonderful treat! The food is consistently fabulous.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'New York City'},
#   {'name': 'Donald',
#    'categories': {'Service': 'Service staff from check in until leaving did a great job',
#     'Food': 'Food was great'},
#    'feedback': 'Service staff from check in until leaving did a great job. Food was great.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Anchorage'}],
#  '28/11/2024': [{'name': 'Manish',
#    'categories': {'Service': 'they have less ppl',
#     'Food': 'and food is much much better'},
#    'feedback': 'Service was not so good , they have less ppl and food on 57 st location is much much better',
#    'rating': 'Overall 2 Food 2 Service 2 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '24/11/2024': [{'name': 'Erik',
#    'categories': {'Service': 'Outstanding service',
#     'Environment': 'and beautiful place to eat and enjoy'},
#    'feedback': 'Outstanding service and beautiful place to eat and enjoy!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 2.0,
#    'city': 'Richmond'},
#   {'name': 'Kara',
#    'categories': {'Food': 'Excellent food', 'Service': 'excellent service'},
#    'feedback': 'Excellent experience excellent food excellent service',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'Frank',
#    'categories': {'Service': 'Joseph and June are the best servers in the place'},
#    'feedback': 'Incredible as usual. Joseph and June are the best servers in the place',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '23/11/2024': [{'name': 'terri',
#    'categories': {'Food': 'the food was amazing'},
#    'feedback': 'We went for my moms 84th birthday.  Everything was perfect and the food was amazing!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Columbus'}],
#  '22/11/2024': [{'name': 'Sami',
#    'categories': {'Service': 'starting at the bar and finalized in the restaurant'},
#    'feedback': 'Another great night starting at the bar and finalized in the restaurant..👏',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Berlin'}],
#  '19/11/2024': [{'name': 'Maria Antónia',
#    'categories': {'Food': 'Rock shrimp is a must',
#     'Service': 'Staff is very nice',
#     'Environment': 'the environment is sophisticated'},
#    'feedback': 'Top! Rock shrimp is a must 🤩\nStaff is very nice and the environment is sophisticated!',
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 5',
#    'stars': 4.7,
#    'city': 'Portugal'}],
#  '17/11/2024': [{'name': 'Elliott',
#    'categories': {'Food': 'Always excellent but first time two items were just ok'},
#    'feedback': 'Always excellent but first time two items were just ok.  All in all amazing though',
#    'rating': 'Overall 4 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '08/11/2024': [{'name': 'James',
#    'categories': {'Service': 'Our waiter was awesome',
#     'Food': 'Food was great',
#     'Environment': 'Restaurant super comfortable'},
#    'feedback': 'Our waiter was awesome.  Food was great. Restaurant super comfortable.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'Greater Boston'}],
#  '07/11/2024': [{'name': 'Jason',
#    'categories': {'Food': 'The meal was delicious',
#     'Service': 'and the service exemplary'},
#    'feedback': 'Had a wonderful client lunch.  The meal was delicious and the service exemplary as always.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '03/11/2024': [{'name': 'John',
#    'categories': {'Food': 'food was fabulous',
#     'Service': 'service is top notch'},
#    'feedback': 'Great restaurant and service. A bit pricey but food was fabulous and service is top notch.\nDefinitely worth the visit.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 2.0,
#    'city': 'New York City'}],
#  '02/11/2024': [{'name': 'Troy',
#    'categories': {'Service': 'Excellent as always. Waiter made some great recommendations'},
#    'feedback': 'Excellent as always. Waiter made some great recommendations.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Columbus'},
#   {'name': 'Shweta',
#    'categories': {'Food': 'Food was just not up to the mark',
#     'Environment': 'Ambience not so great'},
#    'feedback': 'Food was just not up to the mark. Ambience not so great. Wasn’t happy with this Nobu overall',
#    'rating': 'Overall 2 Food 2 Service 5 Ambience 2',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '31/10/2024': [{'name': 'kirsty',
#    'categories': {'Food': 'We had a great meal',
#     'Environment': 'with nice ambience'},
#    'feedback': 'We had a great meal, with nice ambience. I definitely recommend the miso black cod it is so delicious. Sushi rolls were tasty too.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 2.0,
#    'city': 'New York City'}],
#  '30/10/2024': [{'name': 'Kate',
#    'categories': {'Environment': 'sit at the Sushi Counter'},
#    'feedback': 'For the whole experience, sit a the Sushi Counter.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'Rachmaninoff',
#    'categories': {'Food': 'Always great service and food',
#     'Service': 'Our server gave great recommendations'},
#    'feedback': 'Always great service and food\nOur server gave great recommendations',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 5.0,
#    'city': 'Central Texas'}],
#  '24/10/2024': [{'name': 'Gerhard',
#    'categories': {'Environment': 'A little noisy @ bar table'},
#    'feedback': 'A little noisy @ bar table, still a great experience!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 5.0,
#    'city': 'Munich'}],
#  '21/10/2024': [{'name': 'Sara',
#    'categories': {'Service': 'Amazing from the host to waitress',
#     'Food': 'and food was amazing'},
#    'feedback': 'Amazing !!!!! From the host to waitress and food was amazing !',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'San Francisco'}],
#  '20/10/2024': [{'name': 'Todd',
#    'categories': {'Food': 'Food is served randomly for all to share'},
#    'feedback': 'Amazing dining experience.\nFood is served randomly for all to share.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Denver'}],
#  '19/10/2024': [{'name': 'Melissa',
#    'categories': {'Service': 'Our waiter crafted a menu for us based on our preferences and WOW - fabulous'},
#    'feedback': 'We had an amazing dining experience. Our waiter, Joseph, crafted a menu for us based on our preferences and WOW - fabulous!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '13/10/2024': [{'name': 'Sean',
#    'categories': {'Food': 'The sushi stink, tasteless and the rice was all mushy'},
#    'feedback': 'The sushi stink, tasteless and the rice was all mushy.',
#    'rating': 'Overall 1 Food 1 Service 4 Ambience 4',
#    'stars': 5.0,
#    'city': 'E. Tennessee'},
#   {'name': 'Justin',
#    'categories': {'Food': 'Found a hair in my dessert',
#     'Service': 'The service was great but food was okay and left hungry still'},
#    'feedback': 'Found a hair in my dessert. The service was great but food was okay and left hungry still.',
#    'rating': 'Overall 2 Food 2 Service 4 Ambience 3',
#    'stars': 1.0,
#    'city': 'New York City'},
#   {'name': 'Christopher',
#    'categories': {'Food': 'fits the bill on perfect sushi'},
#    'feedback': 'fits the bill on perfect sushi.  Want more. Will go moar',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Washington DC'}],
#  '07/10/2024': [{'name': 'Tommy',
#    'categories': {'Food': 'The food and service are always great',
#     'Service': 'Sushi is always fresh'},
#    'feedback': 'Nobu is the best around. The food and service are always great. Sushi is always fresh. We try to go at least once a month.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'New York City'}],
#  '05/10/2024': [{'name': 'Manuel',
#    'categories': {'Environment': 'Very great ambiance',
#     'Food': 'and the desert is a must'},
#    'feedback': 'Very great ambiance me and my girlfriend enjoyed and the desert is a must',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '30/09/2024': [{'name': 'Jake',
#    'categories': {'Food': 'the food was unbelievable',
#     'Service': 'the service was great'},
#    'feedback': 'Loved it the service was gret all the staff were helpful and the food was unbelievable',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Orange County'},
#   {'name': 'Dora',
#    'categories': {'Food': 'Incredibly fresh and good food',
#     'Service': 'Nice service'},
#    'feedback': 'Incredibly fresh and good food. Nice service. We will return again.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '29/09/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Delicious ! Took my daughter and husband and we enjoyed our meal'},
#    'feedback': 'Delicious !  Took my daughter and husband and we enjoyed our meal !',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Houston'}],
#  '25/09/2024': [{'name': 'Sharkogram',
#    'categories': {'Food': 'Nothing else compares'},
#    'feedback': "It's the only place I'll ever eat sushi. Nothing else compares!",
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Houston'},
#   {'name': 'Rachel',
#    'categories': {'Food': 'The staples and the specials were phenomenal! Loved the vegetables too'},
#    'feedback': 'The staples and the specials were phenomenal! Loved the vegetables too',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '22/09/2024': [{'name': 'Dushyant',
#    'categories': {'Service': 'Check in girl was not good in assigning table'},
#    'feedback': 'Been there before. Check in girl was not good in assigning table.',
#    'rating': 'Overall 4 Food 5 Service 2 Ambience 5',
#    'stars': 5.0,
#    'city': 'Miami'}],
#  '19/09/2024': [{'name': 'Krishna',
#    'categories': {'Service': 'Outstanding customer service',
#     'Food': 'excellent food',
#     'Environment': 'ambiance is breathtaking'},
#    'feedback': 'Outstanding customer service and excellent food.ambiance is breathtaking',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Cleveland'}],
#  '17/09/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Omakase was well deserved by us both'},
#    'feedback': 'It was an anniversary treat.  Omakase was well deserved by us both….she’s worth it!',
#    'rating': 'Overall 5 Food 5 Service 3 Ambience 5',
#    'stars': 4.0,
#    'city': 'Orange County'}],
#  '13/09/2024': [{'name': 'Lauryn',
#    'categories': {'Food': 'Had the lamb chops for the first time...incredible'},
#    'feedback': 'Always incredible. Had the lamb chops for the first time...incredible',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '12/09/2024': [{'name': 'Ashley',
#    'categories': {'Food': 'Our favorite night out in the Financial District always involves Lychee Martinis and Yellowtail with Jalapeños'},
#    'feedback': 'Our favorite night out in the Financial District always involves Lychee Martinis and Yellowtail with Jalapeños!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New Orleans'}],
#  '09/09/2024': [{'name': 'Cassandra',
#    'categories': {'Food': 'Everything tasted amazing',
#     'Service': 'service was quick'},
#    'feedback': '10/10 food and service experience. Everything tasted amazing and service was quick.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '08/09/2024': [{'name': 'julia',
#    'categories': {'Food': 'Outstanding food and service as usual',
#     'Service': 'The edamame choclo and yellowtail jalapeño are amazing'},
#    'feedback': 'Outstanding food and service as usual !! The edamame choclo and yellowtail jalapeño are amazing !!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '06/09/2024': [{'name': 'Willy',
#    'categories': {'Service': 'The staff was warm and welcoming',
#     'Food': 'and the drinks were great, The crispy rice and tuna are a must'},
#    'feedback': 'The staff was warm and welcoming, and the drinks were great. The crispy rice and tuna are a must.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '05/09/2024': [{'name': 'Nino',
#    'categories': {'Food': 'Relatively good food',
#     'Environment': 'I was expecting a kind of a smaller place but it happened that it was not'},
#    'feedback': 'Relatively good food.\nI was expecting a kind of a smaller place but it happened that it was not.\nAnyway I was expecting a kind of more.',
#    'rating': 'Overall 4 Food 4 Service 5 Ambience 3',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '03/09/2024': [{'name': 'Terrance',
#    'categories': {'Food': 'Wagyu dumplings were amazing'},
#    'feedback': 'It’s as good as advertised . Wagyu dumplings were amazing',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Philadelphia'}],
#  '31/08/2024': [{'name': 'Chloe',
#    'categories': {'Food': 'the food was incredible',
#     'Service': 'Very attentive servers'},
#    'feedback': 'Such an amazing experience, and the food was incredible! Very attentive servers and the courses were so thought out. Absolutely coming back.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '28/08/2024': [{'name': 'SatyaR',
#    'categories': {'Service': 'Our hostess was amazing in recommending items',
#     'Food': 'Thoroughly enjoyed our dinner'},
#    'feedback': 'Our hostess was amazing in recommending items for us. Thoroughly enjoyed our dinner at Nobu',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '24/08/2024': [{'name': 'Joseph',
#    'categories': {'Service': "when the desert came out it didn't say anything and no candles"},
#    'feedback': 'It was my wife’s birthday I informed the restaurant but when the desert came out it didn’t say anything and no candles so disappointing',
#    'rating': 'Overall 3 Food 5 Service 2 Ambience 3',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '19/08/2024': [{'name': 'Jennfier',
#    'categories': {'Food': 'Consistently fantastic food',
#     'Service': 'service',
#     'Environment': 'ambiance'},
#    'feedback': 'Consistently fantastic food, service, ambiance….. one of my favorites',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '18/08/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Delicious as always. Nothing better than the crispy rice and the Mia margarita'},
#    'feedback': 'Delicious as always. Nothing better than the crispy rice and the Mia margarita.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'Anthony',
#    'categories': {'Food': 'Love the food', 'Service': 'and the service'},
#    'feedback': 'Many time returning diner.. Love the food and the service .. Brought my daughters for the first time and loved it so much they cant wait to go again',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '16/08/2024': [{'name': 'Andre',
#    'categories': {'Food': 'Classic bento box was fantastic',
#     'Service': 'Service was A+'},
#    'feedback': 'Classic bento box was fantastic.  Service was A+.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'Wntskiing',
#    'categories': {'Food': 'Superb quality and presentation of food and beverages',
#     'Service': 'Knowledgeable staff'},
#    'feedback': 'Superb quality and presentation of food and beverages. Knowledgeable staff. A special experience that we’ll never forget.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Richmond'},
#   {'name': 'Mariam',
#    'categories': {'Environment': 'The ambiance was very pleasant'},
#    'feedback': 'The dining experience was great! The ambiance was very pleasant.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '11/08/2024': [{'name': 'christopher',
#    'categories': {'Environment': 'much better atmosphere for a date'},
#    'feedback': 'Great experience,  ask to side upstairs, much better atmosphere for a date',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'Robert',
#    'categories': {'Food': 'Food was very good and the presentation was artwork'},
#    'feedback': 'Great experience! Food was very good and the presentation was artwork!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Richmond'}],
#  '06/08/2024': [{'name': 'Lauren',
#    'categories': {'Food': 'Meat tacos were awesome'},
#    'feedback': 'Great birthday dinner. Meat tacos were awesome! Will go back!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'New York City'},
#   {'name': 'Mats',
#    'categories': {'Service': 'Superb service our waiter was incredible and soo nice'},
#    'feedback': 'Superb service our waiter was incredible and soo nice, he made the expirience so much better',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Los Angeles'}],
#  '05/08/2024': [{'name': 'Mary',
#    'categories': {'Food': 'Food, as always, was delicious',
#     'Service': 'The service was friendly and efficient'},
#    'feedback': 'Food, as always, was delicious. The service was friendly and efficient.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 4.0,
#    'city': 'New York City'},
#   {'name': 'MichaelW',
#    'categories': {'Service': 'Excellent as always'},
#    'feedback': 'Excellent as always. It’s our family celebration destination',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'Tom',
#    'categories': {},
#    'feedback': 'First time going. Outstanding experience! Can’t wait to go again',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Upstate NY'}],
#  '01/08/2024': [{'name': 'Ponsie',
#    'categories': {'Environment': 'Great vibe all around',
#     'Food': 'Food was excellent'},
#    'feedback': 'Sat at the Sushi Bar downstairs. Great vibe all around.\nFood was excellent. Great Tacos and the Cod to die for!!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Toronto'}],
#  '29/07/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Food was absolutely amazing and so fresh'},
#    'feedback': 'It was amazing. Food was absolutely amazing and so fresh',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  "28/07/2024\n\nNote: I've excluded the price comment as per instructions to ignore pricing information, and the comparison to another location is personal information/different location which should be ignored.": [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Food is good'},
#    'feedback': 'Food is good, but incredibly overpriced for what it is. We had a wonderful experience at the Nobu in West Hollywood, this was far from that.',
#    'rating': 'Overall 3 Food 3 Service 4 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '25/07/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Delicious food',
#     'Environment': 'very good location',
#     'Service': 'friendly service'},
#    'feedback': 'Delicious food, very good location and friendly service.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '21/07/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Portions were very small',
#     'Service': 'Service was amazing',
#     'Environment': 'The noise level was minimal'},
#    'feedback': 'Portions were very small. Service was amazing. The noise level was minimal',
#    'rating': 'Overall 4 Food 5 Service 5 Ambience 3',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'AntonioC',
#    'categories': {'Food': 'Drinks were small and not a real martini glass'},
#    'feedback': 'It’s nice, but for me not worth the price.\nDrinks were small and not a real martini glass.',
#    'rating': 'Overall 3 Food 3 Service 3 Ambience 4',
#    'stars': 5.0,
#    'city': 'San Francisco'}],
#  '14/07/2024': [{'name': 'Gina',
#    'categories': {'Food': 'Delicious food', 'Service': 'excellent staff'},
#    'feedback': 'Delicious food, excellent staff! Worth the splurge.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'JenniferB',
#    'categories': {'Food': 'Freshest fish',
#     'Service': 'attentive and caring team',
#     'Environment': 'beautiful venue'},
#    'feedback': 'Phenomenal in every way.  Freshest fish, gorgeous presentation, beautiful venue, attentive and caring team.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '11/07/2024': [{'name': 'JessicaN',
#    'categories': {'Environment': 'Summer scene is not a normal nobu'},
#    'feedback': 'Summer scene is not a normal nobu. What till after Labor Day',
#    'rating': 'Overall 3 Food 2 Service 3 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'from the food',
#     'Environment': 'the ambiance',
#     'Service': 'but most importantly the service'},
#    'feedback': 'Everything was absolutely amazing, from the food, the ambiance, but most importantly the service. 5 stars!!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '10/07/2024\n\nNote: Since there\'s no specific mention of service or environment, and the review is general praise, I\'ve categorized it under "Food" as it\'s a restaurant review context. Multiple similar praise sentences have been condensed to one representative phrase.': [{'name': 'WilliamP',
#    'categories': {'Food': 'Amazing as usual just amazing'},
#    'feedback': 'Amazing as usual just amazing. The most amazing.  It was amazing.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '29/06/2024': [{'name': 'MariaP',
#    'categories': {'Food': 'We loved! Nobu always delivers',
#     'Service': 'We missed the waiters describing the plates'},
#    'feedback': 'We loved! Nobu always delivers. We missed the waiters describing the plates the way the usually do, and the dish we had in San Diego:fish & chips.',
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '23/06/2024': [{'name': 'Billy',
#    'categories': {'Food': 'Nobu is the finest sushi restaurant in the world'},
#    'feedback': 'Nobu is the finest sushi restaurant in the world?  New York City downtown is one of their best I’ve been to most in the US.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'Cancun'},
#   {'name': 'Vikr',
#    'categories': {'Service': 'Very well attended',
#     'Food': 'the staff was very attentive',
#     'Environment': 'Food and ambiance were also great'},
#    'feedback': 'Very well attended. Came here for my son’s birthday and the staff was very attentive. Food and ambiance were also great',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '22/06/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'food is amazing',
#     'Service': 'staff also amazing',
#     'Environment': 'great atmosphere'},
#    'feedback': 'If you love sushi you can’t go wrong with any dish went twice with my girlfriend food is amazing staff also amazing on point great atmosphere also !',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'monica',
#    'categories': {'Food': 'DELICIOSO TODO',
#     'Environment': 'EL AMBIENTE NOS ENCANTO',
#     'Service': 'LA ATENCION DE TODO EL PERSONAL EXCELENTE'},
#    'feedback': 'DELICIOSO TODO , EL AMBIENTE NOS ENCANTO , LA ATENCION DE TODO EL PERSONAL EXCELENTE',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Monterrey'},
#   {'name': 'JasonK',
#    'categories': {'Food': 'The food at Nobu downtown is mediocre',
#     'Environment': 'Ambiance is also lacking'},
#    'feedback': 'The food at Nobu downtown is mediocre. Like eating at a national chain restaurant. Ambiance is also lacking - random mix.',
#    'rating': 'Overall 1 Food 1 Service 2 Ambience 2',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '21/06/2024': [{'name': 'Boris',
#    'categories': {'Food': 'Nobu is and always will be the best'},
#    'feedback': 'Nobu is and always will be the best. In the world.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'New York City'},
#   {'name': 'Paddington',
#    'categories': {'Food': "I've loved every single meal",
#     'Service': 'the sushi master who took care of us was outstanding',
#     'Environment': 'I adore sitting at the sushi bar'},
#    'feedback': 'I’ve loved every single meal I’ve ever had at Nobu. I adore sitting at the sushi bar, and the sushi master who took care of us was outstanding.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'Los Angeles'}],
#  '17/06/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'THE BEST SERVICE IN THE CITY'},
#    'feedback': 'THE BEST SERVICE IN THE CITY. WILL ALWAYS COME BACK TO NOBU DOWNTOWN🫶🏾',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Los Angeles'}],
#  '16/06/2024': [{'name': 'AngieD',
#    'categories': {'Service': 'Our waiter was phenomenal'},
#    'feedback': 'Our waiter, Chris, was phenomenal! He was kind and personable.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Minneapolis'}],
#  '09/06/2024': [{'name': 'HowardG',
#    'categories': {'Food': 'We had an amazing meal',
#     'Service': 'only to be accompanied by great service'},
#    'feedback': 'We had an amazing meal only to be accompanied by great service from our waitress, June.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '05/06/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Uni and the Wagyu nigiri are awesome, so is the sake'},
#    'feedback': 'Always a great experience. Uni and the Wagyu nigiri are awesome, so is the sake',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Milwaukee'}],
#  '02/06/2024': [{'name': 'RichB',
#    'categories': {'Food': 'Very good food'},
#    'feedback': 'Very good food. On the pricey side for what it is...still good though',
#    'rating': 'Overall 4 Food 4 Service 4 Ambience 4',
#    'stars': 5.0,
#    'city': 'Central Coast'}],
#  '31/05/2024': [{'name': 'christine',
#    'categories': {'Food': 'Nobu is always amazing'},
#    'feedback': 'Nobu is always amazing no matter what country you’re in!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'San Diego'}],
#  '26/05/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Environment': 'Great table',
#     'Food': 'great meal',
#     'Service': 'great service'},
#    'feedback': 'Great table, great meal, great service. We had a wonderful time.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '24/05/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'Great service', 'Food': 'and good food'},
#    'feedback': 'Great service and good good. Our entire group really enjoyed it',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Denver'}],
#  '19/05/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Environment': 'We sat upstairs in the lounge area and absolutely loved it',
#     'Service': 'Service was top notch',
#     'Food': 'the food was superb'},
#    'feedback': 'Nobu never disappoints! We sat upstairs in the lounge area and absolutely loved it! Service was top notch and the food was superb!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '18/05/2024': [{'name': 'aneleh',
#    'categories': {'Food': 'Average food', 'Environment': 'noisy environment'},
#    'feedback': 'Average food, noisy environment, poor value for money',
#    'rating': 'Overall 3 Food 3 Service 4 Ambience 3',
#    'stars': 5.0,
#    'city': 'London'}],
#  '17/05/2024': [{'name': 'ChrisG',
#    'categories': {'Service': 'They know how to do it'},
#    'feedback': 'Great meal with my son for his birthday. They know how to do it. Pure and simple that if you are on the fence about going to Nobu don’t be!!!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '16/05/2024': [{'name': 'Kabbage',
#    'categories': {'Environment': 'Ambiance is cool',
#     'Food': 'Food was creative but portions are small'},
#    'feedback': 'It’s a place to take someone to impress. Ambiance is cool. Food was creative but way overpriced for what you get. Portions are small.',
#    'rating': 'Overall 4 Food 4 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'San Francisco'}],
#  '13/05/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'Staff was very accommodating',
#     'Food': 'food was fantastic'},
#    'feedback': 'My date and I had a great time.  Staff was very accommodating and food was fantastic.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '08/05/2024': [{'name': 'vincentp',
#    'categories': {'Environment': 'Excellent ambience',
#     'Food': 'and food',
#     'Service': 'the service was great'},
#    'feedback': 'Excellent ambience and food , the service was great !!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '05/05/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'Our server was fantastic',
#     'Food': "food was best we've ever had"},
#    'feedback': 'Incredible from start to end. Our server was fantastic, food was best we’ve ever had. Once in a lifetime experience',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'San Francisco'}],
#  '04/05/2024': [{'name': 'Izzy',
#    'categories': {'Service': 'People are gracious',
#     'Food': 'food is wonderful'},
#    'feedback': 'We love Nobu! People are gracious and food is wonderful.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Denver'}],
#  '02/05/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Cibo Tom',
#     'Service': 'Servizi preciso',
#     'Environment': 'in un ambiente fantastico'},
#    'feedback': 'Cibo Tom in un ambiente fantastico. Servizi preciso',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '28/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Need more options on menu for food and drink',
#     'Service': 'Service was great!',
#     'Environment': 'Cool building'},
#    'feedback': 'Need more options on menu for food and drink. Cool building. Service was great!',
#    'rating': 'Overall 2 Food 3 Service 3 Ambience 4',
#    'stars': 5.0,
#    'city': 'Philadelphia'}],
#  '27/04/2024': [{'name': 'MarvinP',
#    'categories': {'Environment': 'The vibes was incredible',
#     'Service': 'and our waitress was out of this world very informative and helpful'},
#    'feedback': 'The vibes was incredible and our waitress was out of this world very informative and helpful. I loved the whole experience.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'Sushi was amazing',
#     'Service': 'Excellent service and menu selection'},
#    'feedback': 'Unique dinner experience.  Excellent service and menu selection.  Wait staff suggestions were superb.  Sushi was amazing.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 2.0,
#    'city': 'Cleveland'}],
#  '26/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Food and drinks were great',
#     'Environment': "The location of the table was at the very back by the kitchen, which we didn't like"},
#    'feedback': 'Food and drinks were great. The location of the table was at the very back by the kitchen, which we didn’t like.',
#    'rating': 'Overall 4 Food 5 Service 5 Ambience 3',
#    'stars': 5.0,
#    'city': 'Chicago'}],
#  '24/04/2024': [{'name': 'VickiB',
#    'categories': {'Food': 'Awesome food', 'Environment': 'and ambiance'},
#    'feedback': 'Awesome food and ambiance. Great for special celebration! Will def go back!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'LauriN',
#    'categories': {'Environment': 'Great atmosphere', 'Food': 'and food'},
#    'feedback': 'Great atmosphere and food!! Love the discrete location.',
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 5',
#    'stars': 5.0,
#    'city': 'Chicago'}],
#  '18/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'The food was excellent'},
#    'feedback': 'Great experience overall. The food was excellent.',
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '17/04/2024': [{'name': 'Mzles',
#    'categories': {'Food': 'Food was awesome, I had the bento box'},
#    'feedback': 'Great experience! Food was awesome, I had the bento box.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 3.0,
#    'city': 'Philadelphia'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'Amazing food',
#     'Environment': 'great ambiance',
#     'Service': 'superb service'},
#    'feedback': 'Amazing food, great ambiance, superb service. We loved it.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Seattle'}],
#  '14/04/2024': [{'name': 'TimothyW',
#    'categories': {'Food': 'The yellowtail and jalapeno is a favorite dish of ours',
#     'Service': 'The waitress was awesome',
#     'Environment': 'and the ambiance was perfect'},
#    'feedback': 'The yellowtail and jalapeno is a favorite dish of ours. The waitress was awesome and the ambiance was perfect.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'Another great meal',
#     'Service': 'dining experience at downtown Nobu'},
#    'feedback': 'Another great meal and dining experience at downtown Nobu . It was our son’s birthday and they made him feel special.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 2.0,
#    'city': 'Poconos'}],
#  '12/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'Wonderful! Our waiter could not have been more helpful and accommodating'},
#    'feedback': 'Wonderful! Our waiter could not have been more helpful and accommodating.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Charleston'},
#   {'name': 'veronica',
#    'categories': {'Environment': 'Troppo rumoroso, da mal di testa!',
#     'Food': 'Cibo ottimo',
#     'Service': 'servizio mediocre'},
#    'feedback': 'Troppo rumoroso, da mal di testa!\nCibo ottimo, servizio mediocre.',
#    'rating': 'Overall 4 Food 4 Service 3 Ambience 4',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Service': 'the service was amazing'},
#    'feedback': 'As always, the service was amazing, esp the gang welcoming our group at the  front door.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '08/04/2024': [{'name': 'DouglasT',
#    'categories': {'Food': 'Sushi and sashimi platters came so quickly seemed like they had to have been made in advance',
#     'Service': 'Good not great'},
#    'feedback': 'Sushi and sashimi platters came so quickly seemed like they had to have been made in advance.   Good not great.',
#    'rating': 'Overall 4 Food 4 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'},
#   {'name': 'ShearaG',
#    'categories': {'Food': 'food amazing',
#     'Service': 'Service exceptional',
#     'Environment': 'Loved the ambiance'},
#    'feedback': 'FABULOUS!!! Service exceptional, food amazing! Loved the ambiance as well. Highly recommended!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Chicago'}],
#  '07/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'The staff was very nice',
#     'Environment': 'and the downstairs had a good ambiance'},
#    'feedback': 'The staff was very nice and the downstairs had a good ambiance',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '06/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Wonderful place',
#     'Service': 'service',
#     'Environment': 'and amazing food'},
#    'feedback': 'Wonderful place, service, and amazing food I’ll definitely be back it was one of the best meals I’ve ever had.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Detroit'},
#   {'name': 'SandraS',
#    'categories': {'Environment': 'Very noisy experience',
#     'Food': 'Food was good, but did not meet our expectations'},
#    'feedback': 'Very noisy experience! Overrated in my opinion… Food was good, but did not meet our expectations.',
#    'rating': 'Overall 3 Food 3 Service 3 Ambience 3',
#    'stars': 4.7,
#    'city': 'Las Vegas'}],
#  '02/04/2024': [{'name': 'MartinW',
#    'categories': {'Food': 'I was a little bit disappointed'},
#    'feedback': 'Not the best Nobu.. I was a little bit disappointed, because normally Nobu is always stunning!',
#    'rating': 'Overall 3 Food 3 Service 4 Ambience 4',
#    'stars': 3.0,
#    'city': 'Bavaria'}],
#  '01/04/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': "Nothing beats Nobu almost 20 years we've been going!"},
#    'feedback': 'Nothing beats Nobu almost 20 years we’ve been going!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Costa Rica'}],
#  '31/03/2024': [{'name': 'pchak',
#    'categories': {'Food': 'Best things we ate were the Yellow Tail, Black Cod with miso, and the Lobster Tempura'},
#    'feedback': 'Lived up to the hype! Best things we ate were the Yellow Tail, Black Cod with miso, and the Lobster Tempura!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'Washington DC'}],
#  '30/03/2024': [{'name': 'TaiA',
#    'categories': {'Food': 'Delicious', 'Environment': 'Hard to find, lovely'},
#    'feedback': 'Overall great experience. Hard to find, lovely! Delicious.',
#    'rating': 'Overall 5 Food 4 Service 5 Ambience 4',
#    'stars': 1.0,
#    'city': 'New York City'}],
#  '29/03/2024': [{'name': 'NatalieE',
#    'categories': {'Food': 'Always great fresh food',
#     'Service': 'Good service',
#     'Environment': 'Nice vibe'},
#    'feedback': 'Always great fresh food. Good service. Nice vibe. Love it',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '27/03/2024': [{'name': 'SusieQs',
#    'categories': {'Service': 'The staff is incredible',
#     'Food': 'the food is divine'},
#    'feedback': 'Wonderful and consistent experience every time! The staff is incredible, the food is divine! Thank you for another fantastic meal!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '22/03/2024': [{'name': 'Kim89',
#    'categories': {'Service': 'Extremely bad service',
#     'Food': 'however the food was good'},
#    'feedback': 'Extremely bad service, however the food was good. Pity about the service.',
#    'rating': 'Overall 3 Food 4 Service 1 Ambience 4',
#    'stars': 4.7,
#    'city': 'Dublin'}],
#  '12/03/2024': [{'name': 'GailS',
#    'categories': {'Food': 'Amazing food',
#     'Service': 'the service is excellent'},
#    'feedback': 'Amazing food! Worth every penny, the service is excellent.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'Las Vegas'}],
#  '10/03/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Service': "Servier wasn't giving his 100%"},
#    'feedback': 'Servier wasn’t giving his 100%. He didn’t care much',
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '29/02/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'terrible menu'},
#    'feedback': 'Terribly over priced for the quality terrible menu',
#    'rating': 'Overall 2 Food 1 Service 5 Ambience 3',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '27/02/2024': [{'name': 'Aramise',
#    'categories': {'Service': 'Staff was amazing',
#     'Food': 'Food was spectacular',
#     'Environment': 'Ambiance unmatched'},
#    'feedback': 'Outstanding experience .Staff was amazing \nFood was spectacular.Ambiance unmatched \nWill be back soon',
#    'rating': 'Overall 5 Food 4 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '25/02/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Great place with great food'},
#    'feedback': 'Great place with great food.  Somewhat pricey, but it’s good',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 2.0,
#    'city': 'New York City'}],
#  '24/02/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': "Best dinner I've ever had"},
#    'feedback': 'Best dinner I’ve ever had. Amazing experience and will recommend to everyone',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'brianb',
#    'categories': {'Food': 'Amazing dishes'},
#    'feedback': 'Amazing dishes. Expensive but it’s nobu so you know that going in',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '23/02/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Environment': 'The music can be a little lower upstairs'},
#    'feedback': 'Nobu continues to be one of my favorites. The music can be a little lower upstairs.',
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 5',
#    'stars': 3.0,
#    'city': 'Caribbean'},
#   {'name': 'JoanS',
#    'categories': {'Food': 'Exquisitely prepared',
#     'Environment': 'Beautiful space'},
#    'feedback': 'Exquisitely prepared — perfect in every way. Beautiful space to boot. Will return.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '21/02/2024': [{'name': 'BrianA',
#    'categories': {'Food': 'Great meal',
#     'Service': 'and the service was top notch'},
#    'feedback': 'Great meal and the service was top notch! It made a special day even better',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'Delicious, fresh sushi',
#     'Service': 'Excellent service'},
#    'feedback': 'Amazing experience. Delicious, fresh sushi. Excellent service.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Sacramento'}],
#  '15/02/2024': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'an amazing experience'},
#    'feedback': 'It was a great time!! A little pricy, but an amazing experience!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Houston'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'Omakase prix fixe menu was incredible',
#     'Service': 'and the waiter was very accommodating'},
#    'feedback': 'Omakase prix fixe menu was incredible and the waiter was very accommodating',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Pittsburgh'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'I thought the food was mediocre'},
#    'feedback': 'For all the hype about this place unfortunately it an okay experience but nothing special. I thought the food was mediocre.  Very disappointing.',
#    'rating': 'Overall 3 Food 3 Service 3 Ambience 2',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '14/02/2024': [{'name': 'Sally',
#    'categories': {'Food': 'There was a piece of plastic wrapper in my food in the crispy rice tuna'},
#    'feedback': 'There was a piece of plastic wrapper in my food in the crispy rice tuna.',
#    'rating': 'Overall 3 Food 2 Service 5 Ambience 4',
#    'stars': 3.0,
#    'city': 'San Francisco'}],
#  '10/02/2024': [{'name': 'AnthonyG',
#    'categories': {'Food': 'Fantastic food'},
#    'feedback': 'It is all it is cracked up\nTo be.  Fantastic food.  Fantastic',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'},
#   {'name': 'AsiaG',
#    'categories': {'Food': 'Amazing experience', 'Service': 'delicious food'},
#    'feedback': 'Amazing experience and delicious food! Celebrated our son’s birthday and we couldn’t have been happier!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 4',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '05/02/2024': [{'name': 'AddyfromAustraliaMelb',
#    'categories': {'Food': 'Very nice salmon was best'},
#    'feedback': 'Very nice salmon was best. Thanks food was awesome',
#    'rating': 'Overall 5 Food 4 Service 4 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '04/02/2024': [{'name': 'KellyL',
#    'categories': {'Food': 'Absolutely beautiful food',
#     'Service': 'the staff could not do enough for us',
# ...
#    'categories': {'Food': "It's a great experience"},
#    'feedback': "It's a great experience, but prepare your wallet :)",
#    'rating': 'Overall 4 Food 4 Service 4 Ambience 4',
#    'stars': 4.0,
#    'city': 'New York City'},
#   {'name': 'Customer',
#    'categories': {'Food': 'the sushi plate I ordered was not very good'},
#    'feedback': 'the restaurant has a large selection of dishes, the sushi plate I ordered was not very good',
#    'rating': 'Overall 3 Food 3 Service 4 Ambience 4',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '09/03/2022': [{'name': 'EugeneD',
#    'categories': {'Food': 'The food, drinks, and service were excellent',
#     'Service': 'Our server was extremely knowledgeable and helpful'},
#    'feedback': 'Had a great time! The food, drinks, and service were excellent. Our server was extremely knowledgeable and helpful. Would definitely recommend.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'AlvinZ',
#    'categories': {'Food': 'Great place to de-stress',
#     'Environment': 'and enjoy good food'},
#    'feedback': 'Great place to de-stress and enjoy good food! WELL DONE!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '08/03/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Good food'},
#    'feedback': 'Good food. Serving sizes could be a little bigger',
#    'rating': 'Overall 4 Food 4 Service 4 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'Frank',
#    'categories': {'Food': 'Great food',
#     'Environment': 'and atmosphere was amazing'},
#    'feedback': 'Great food and atmosphere was amazing!  Very busy on a Monday evening!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '07/03/2022': [{'name': 'Blooming2',
#    'categories': {'Food': 'The food and service were excellent',
#     'Service': 'The fish is very fresh'},
#    'feedback': 'We had a very enjoyable meal. The food and service were excellent. The fish is very fresh.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '06/03/2022': [{'name': 'MiaG',
#    'categories': {'Food': 'Food is outstanding!',
#     'Service': 'Service was impeccable',
#     'Environment': 'The restaurant is loud and very dark'},
#    'feedback': 'Food is outstanding! Service was impeccable..The restaurant is loud and very dark.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'AlexH',
#    'categories': {'Food': 'It was a phenomenal meal',
#     'Service': 'Our waitress was so kind and made sure that we always had something on the table'},
#    'feedback': 'It was a phenomenal meal. Our waitress was so kind and made sure that we always had something on the table. An amazing first date experience!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Washington DC'},
#   {'name': 'AyanaD',
#    'categories': {'Food': 'Food was delicious',
#     'Service': 'Our host gave us excellent dinner suggestions'},
#    'feedback': 'Food was delicious I have zero complaints . First time  there and was very pleased. Our host gave us excellent dinner suggestions',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '05/03/2022': [{'name': 'AleidaC',
#    'categories': {'Service': 'Amazing service',
#     'Food': 'The food was out of this world'},
#    'feedback': 'Amazing service. The food was out of this world. Drinks were excellent. Totally recommend!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Orlando'}],
#  '03/03/2022': [{'name': 'Myork',
#    'categories': {'Service': 'Rushed out, not able to have a nicely paced meal'},
#    'feedback': 'Rushed out, not able to have a nicely paced meal',
#    'rating': 'Overall 3 Food 4 Service 4 Ambience 2',
#    'stars': 4.0,
#    'city': 'New York City'},
#   {'name': 'CezaryP',
#    'categories': {'Service': 'No chance to eat them even warm'},
#    'feedback': 'All hot dishes from Chef’s menu served at the same time. No chance to eat them even warm.',
#    'rating': 'Overall 3 Food 3 Service 3 Ambience 4',
#    'stars': 5.0,
#    'city': 'Toronto'}],
#  '02/03/2022': [{'name': 'LauraK',
#    'categories': {'Food': 'Nobu was everything we expected'},
#    'feedback': 'Nobu was everything we expected. I want to go back ASAP!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'Indiana'}],
#  '27/02/2022': [{'name': 'SoniaP',
#    'categories': {'Food': 'High quality food',
#     'Service': 'very knowledgeable staff'},
#    'feedback': 'Great night out! High quality food and very knowledgeable staff…recommendations 100% !!! Wish I could dine here every night !!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '25/02/2022': [{'name': 'TatoA',
#    'categories': {'Environment': 'Beautiful interiors',
#     'Service': 'excellent service',
#     'Food': 'delicious food'},
#    'feedback': 'Beautiful interiors, excellent service, delicious food',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Monaco'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'The food was delicious and the drinks were on point'},
#    'feedback': 'Went for dinner for my daughter’s birthday. The food was delicious and the drinks were on point 👌🏾',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '23/02/2022': [{'name': 'SITT',
#    'categories': {'Service': 'Very helpful staff',
#     'Food': 'food was very good and tasted great'},
#    'feedback': 'Very helpful staff and food was very good.\nWe had vegetable sushi and some desserts.\nEverything was fresh and tasted great',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '21/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'amazing food'},
#    'feedback': 'amazing food',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '20/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Service': 'Service was really good',
#     'Food': 'and food even better',
#     'Environment': 'The atmosphere was really nice'},
#    'feedback': 'Service was really good and food even better. The atmosphere was really nice.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'Emajy',
#    'categories': {'Food': 'Great dinner as usual',
#     'Service': 'Waiter made excellent recommendations'},
#    'feedback': 'Great dinner as usual. Pricy but you know what your getting. Waiter made excellent recommendations',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '19/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Delicioso', 'Service': 'Servicio excelente'},
#    'feedback': 'Delicioso y el\nServicio excelente',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '18/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Environment': 'The debris that fell on our heads',
#     'Service': 'But the manager was excellent'},
#    'feedback': 'Everything good apart from\nThe debris that fell on our heads!  But the manager was excellent',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'LucianaF',
#    'categories': {'Food': 'Food is amazing'},
#    'feedback': 'Food is amazing but very expensive',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'London'}],
#  '17/02/2022': [{'name': 'KarenHNYC',
#    'categories': {'Food': 'the fish was superb and our meal was fantastic'},
#    'feedback': "Such a noticeable upgrade from 'everyday' sushi -- the fish was superb and our meal was fantastic, thank you.",
#    'rating': 'Overall 5 Food 5 Service 4 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '16/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': "Valentine's Day diner was excellent"},
#    'feedback': 'Valentine’s Day (after) diner was excellent! Definitely going again.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'SilviaG',
#    'categories': {'Food': 'The food is always amazing',
#     'Service': 'the service impeccable',
#     'Environment': 'great atmosphere'},
#    'feedback': "LOVE Nobu! The food is always amazing, the service impeccable, great atmosphere, and my teen daughters felt like Queens! We'll be back.",
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '15/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Food is great'},
#    'feedback': 'Valentine’s Day dinner was amazing! Food is great!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Philadelphia'},
#   {'name': 'ShimraniB',
#    'categories': {'Food': 'The food was okay',
#     'Service': "staff didn't feel friendly",
#     'Environment': 'Ambience was great though'},
#    'feedback': 'The food was okay, staff didn’t feel friendly. Ambience was great though.',
#    'rating': 'Overall 3 Food 3 Service 3 Ambience 4',
#    'stars': 4.0,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Environment': 'gnats flying around the table'},
#    'feedback': 'Everything was great except for the gnats flying around the table!',
#    'rating': 'Overall 3 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'We thought the food for the Valentines dinner was creative and fun',
#     'Service': 'service as always was excellent',
#     'Environment': 'Nice buzz'},
#    'feedback': 'We thought the food for the Valentines dinner was creative and fun- service as always was excellent! Nice buzz.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 2.0,
#    'city': 'New York City'}],
#  '13/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Great food'},
#    'feedback': 'Great food',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '12/02/2022': [{'name': 'SydneyE',
#    'categories': {'Food': 'Sooooo good'},
#    'feedback': 'Sooooo good. Highly recommend. Somewhat tapas style.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Washington DC'},
#   {'name': 'NYTEV',
#    'categories': {'Service': 'Service was Top 5'},
#    'feedback': 'Had such a calm amazing time at Nobu Downtown. Service was Top 5, no debate. I enjoyed every moment. Highly Recommended !',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'San Francisco'},
#   {'name': 'CesM',
#    'categories': {'Service': 'Amazing! We left our entire order up to our server and she brought out one delicious dish after another'},
#    'feedback': 'Amazing! We left our entire order up to our server and she brought out one delicious dish after another!!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Dallas'},
#   {'name': 'Torry',
#    'categories': {'Food': 'definitely get the spicy tuna with rice',
#     'Service': 'our bartender upstairs was the best'},
#    'feedback': 'definitely get the spicy tuna with rice app. our bartender upstairs was the best',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'Coastal Georgia'}],
#  '08/02/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Environment': 'a nice atmosphere',
#     'Food': 'great food and drink'},
#    'feedback': 'Nobu downtown is a wonderful restaurant with a nice atmosphere, great food and drink.  Recommended.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '04/02/2022': [{'name': 'RickTaylor',
#    'categories': {'Food': "Can't miss with Nobu"},
#    'feedback': 'Can’t miss with Nobu.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '30/01/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'food was great'},
#    'feedback': 'food was great',
#    'rating': 'Overall 3 Food 3 Service 2 Ambience 4',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '29/01/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'average food', 'Service': 'crappy service'},
#    'feedback': 'Way over priced for average food and crappy service.',
#    'rating': 'Overall 1 Food 1 Service 1 Ambience 4',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'ThomasS',
#    'categories': {'Service': 'Amazing. We had a wonderful time'},
#    'feedback': 'Amazing. We had a wonderful time.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'},
#   {'name': 'PaulM',
#    'categories': {'Environment': 'Excellent atmosphere',
#     'Food': 'great food with a twist'},
#    'feedback': 'Excellent atmosphere and great food with a twist..',
#    'rating': 'Overall 5 Food 4 Service 5 Ambience 5',
#    'stars': 1.0,
#    'city': 'New York City'},
#   {'name': 'OpenTable Diner',
#    'categories': {'Food': 'A great spin on high quality Japanese cuisine',
#     'Environment': 'Great spot for a date'},
#    'feedback': 'Incredible experience. A great spin on high quality Japanese cuisine. \n\nGreat spot for a date. DEFINITELY get a reservation ahead of time.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '25/01/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Amazing food', 'Environment': 'and vibe'},
#    'feedback': 'Amazing food and vibe 10/10 will be back soon.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '22/01/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'Food was really good',
#     'Service': "And it's was made quickly"},
#    'feedback': 'Decent. Food was really good. And it’s was made quickly.',
#    'rating': 'Overall 4 Food 4 Service 3 Ambience 5',
#    'stars': 5.0,
#    'city': 'Las Vegas'},
#   {'name': 'Laura',
#    'categories': {'Food': 'Amazing food', 'Service': 'and service'},
#    'feedback': 'Amazing food and service!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 3.0,
#    'city': 'New York City'}],
#  '21/01/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'The best sushi in NYC'},
#    'feedback': 'The best sushi in NYC ❤️❤️I love nobu',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.0,
#    'city': 'New York City'}],
#  '18/01/2022': [{'name': 'schuylerk',
#    'categories': {'Food': 'Food was amazing'},
#    'feedback': 'Food was amazing',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}],
#  '17/01/2022': [{'name': 'OpenTable Diner',
#    'categories': {'Food': 'the martini espresso is to die for'},
#    'feedback': 'Literally my favorite restaurant. It’s 5/5 every time and the martini espresso is to die for!!',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'New York City'}],
#  '16/01/2022': [{'name': 'palizad',
#    'categories': {'Food': 'Really great time and food'},
#    'feedback': 'Really great time and food. We really enjoyed our date night at Nobu.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 4.7,
#    'city': 'Atlanta Metro'},
#   {'name': 'SpecialK',
#    'categories': {'Environment': 'The street level bar area was gorgeous',
#     'Service': 'Excellent service',
#     'Food': 'Excellent food'},
#    'feedback': 'The street level bar area was gorgeous! Excellent atmosphere, service and food. Will visit again.',
#    'rating': 'Overall 5 Food 5 Service 5 Ambience 5',
#    'stars': 5.0,
#    'city': 'New York City'}]}

# %%
queryFun(f" Great dinner and great, fast service. The food was excellent. Dined on November 11, 2023 (today's date = {formatted_date})")
